# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg" />
#
# ## [mlcourse.ai](https://mlcourse.ai) – Open Machine Learning Course
# Authors: [Yury Kashnitsky](https://yorko.github.io) (@yorko), Yury Isakov. Edited by Anna Tarelina (@feuerengel), Aditya Soni (@ecdrid) and Kolchenko Sergey (@KolchenkoSergey). This material is subject to the terms and conditions of the [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/) license. Free use is permitted for any non-commercial purpose.

# %% [markdown]
# # <center> Assignment #3. Fall 2019
# ## <center> Part 1. User Identification with Logistic Regression <br>(beating baselines in the "Alice" competition)
#
#
# Today we are going to practice working with sparse matrices, training Logistic Regression models, and doing feature engineering. We will reproduce a couple of baselines in the  Kaggle Inclass competition ["Catch Me If You Can: Intruder Detection through Webpage Session Tracking"](https://www.kaggle.com/c/catch-me-if-you-can-intruder-detection-through-webpage-session-tracking2) (a.k.a. "Alice"). More credits will be given for beating stronger baselines.
#
# Prior to working on the assignment, you'd better check out the corresponding course material:
#  1. [Classification, Decision Trees and k Nearest Neighbors](https://nbviewer.jupyter.org/github/Yorko/mlcourse_open/blob/master/jupyter_english/topic03_decision_trees_kNN/topic3_decision_trees_kNN.ipynb?flush_cache=true), the same as an interactive web-based [Kaggle Kernel](https://www.kaggle.com/kashnitsky/topic-3-decision-trees-and-knn) (basics of machine learning are covered here)
#  2. Linear classification and regression in 5 parts:
#     - [ordinary least squares](https://www.kaggle.com/kashnitsky/topic-4-linear-models-part-1-ols)
#     - [linear classification](https://www.kaggle.com/kashnitsky/topic-4-linear-models-part-2-classification)
#     - [regularization](https://www.kaggle.com/kashnitsky/topic-4-linear-models-part-3-regularization)
#     - [logistic regression: pros and cons](https://www.kaggle.com/kashnitsky/topic-4-linear-models-part-4-more-of-logit)
#     - [validation](https://www.kaggle.com/kashnitsky/topic-4-linear-models-part-5-validation)
#  3. You can also practice with demo assignments, which are simpler and already shared with solutions:
#     - "Sarcasm detection with logistic regression": [assignment](https://www.kaggle.com/kashnitsky/a4-demo-sarcasm-detection-with-logit) + [solution](https://www.kaggle.com/kashnitsky/a4-demo-sarcasm-detection-with-logit-solution)
#     - "Linear regression as optimization": [assignment](https://www.kaggle.com/kashnitsky/a4-demo-linear-regression-as-optimization) (solution cannot be officially shared)
#     - "Exploring OLS, Lasso and Random Forest in a regression task": [assignment](https://www.kaggle.com/kashnitsky/a6-demo-linear-models-and-rf-for-regression) + [solution](https://www.kaggle.com/kashnitsky/a6-demo-regression-solution)
#  4. Alice baseline with logistic regression and "bag of sites", [Kernel](https://www.kaggle.com/kashnitsky/alice-logistic-regression-baseline)
#  5. Correct time-aware cross-validation scheme, more features, and hyperparameter optimization, [Kernel](https://www.kaggle.com/kashnitsky/correct-time-aware-cross-validation-scheme)
#  6. **"Model validation in a competition"**, [Kernel](https://www.kaggle.com/kashnitsky/model-validation-in-a-competition) - this one reproduces a solution with **0.95055** Public LB ROC AUC and gives a lot of hints how to proceed with this competition
#  7. Other [Kernels](https://www.kaggle.com/c/catch-me-if-you-can-intruder-detection-through-webpage-session-tracking2/kernels?sortBy=voteCount&group=everyone&pageSize=20&competitionId=7173) in this competition. You can share yours as well, but not high-performing ones (Public LB ROC AUC shall be < 0.95055). Please don't spoil the competitive spirit.
#  8. If that's still not enough, watch two videos on logistic regression: [mlcourse.ai/lectures](https://mlcourse.ai/lectures)
#
# **Your task:**
#  1. "Follow me". Complete the missing code and submit your answers via [the google form](https://docs.google.com/forms/d/1a2PrdKsc7gV2fO7bSwO-uGVEWAY6CIxx-9YV5RNnDIs). Use **the same email and name** as in A1 and A2 (for newcomers: remember your email and use it for all forms during the course). 10 credits max. for this part
#  2. "Freeride". Come up with good features to beat the baselines "A3 baseline (10 credits)" (**0.95343** Public LB ROC-AUC, press "Load more" in the bottom of the [Leaderboard](https://www.kaggle.com/c/catch-me-if-you-can-intruder-detection-through-webpage-session-tracking2/leaderboard) to actually see it) and "A3 strong baseline (20 credits)" (**0.95965** Public LB ROC-AUC). As names suggest, you'll get 10 more credits for beating the first one, and 10 more (20 in total) for beating the second one. You need to name your [team](https://www.kaggle.com/c/catch-me-if-you-can-intruder-detection-through-webpage-session-tracking2/team) (out of 1 person) in full accordance with the [course rating](https://docs.google.com/spreadsheets/d/15e1K0tg5ponA5R6YQkZfihrShTDLAKf5qeKaoVCiuhQ/) (for newcomers: you need to name your team with your real full name). You can think of it as a part of the assignment.
#  3. If you've beaten "A3 baseline (10 credits)" or performed better, you need to upload your solution as described in [course roadmap](https://mlcourse.ai/roadmap) ("Kaggle Inclass Competition Alice" -> Rules). For all baselines that you see on Public Leaderboard, it's OK to beat them on Public LB as well. But 10 winners will be defined according to the private LB, which will be revealed by @yorko on October 27.
#
# ### <center> Deadline for A3: 2019 October 27, 20:59 GMT+1 (London time)

# %% [markdown]
# # Subpart 1. Follow me

# %% [markdown]
# <img src='../../img/followme_alice.png' width=50%>
#
# *image credit [@muradosmann](https://www.instagram.com/muradosmann/?hl=en)*

# %%
# Import libraries and set desired options
import pickle
from pathlib2 import Path
import numpy as np
import pandas as pd
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ##### Problem description
#
# In this competition, we'll analyze the sequence of websites consequently visited by a particular person and try to predict whether this person is Alice or someone else. As a metric we will use [ROC AUC](https://en.wikipedia.org/wiki/Receiver_operating_characteristic).

# %% [markdown]
# ### 1. Data Downloading and Transformation
# Go to the competition [page](https://inclass.kaggle.com/c/catch-me-if-you-can-intruder-detection-through-webpage-session-tracking2) and download the data.
#
# First, read the training and test sets. Then we'll explore the data in hand and do a couple of simple exercises.

# %%
# Read the training and test data sets, change paths if needed
PATH_TO_DATA = Path('alice/')

times = ['time%s' % i for i in range(1, 11)]
train_df = pd.read_csv(PATH_TO_DATA / 'train_sessions.csv',
                       index_col='session_id', parse_dates=times)
test_df = pd.read_csv(PATH_TO_DATA / 'test_sessions.csv',
                      index_col='session_id', parse_dates=times)

# Sort the data by time
train_df = train_df.sort_values(by='time1')

# Look at the first rows of the training set
train_df.head()
# Out:
#             site1               time1  site2               time2  site3  \
# session_id
# 21669          56 2013-01-12 08:05:57   55.0 2013-01-12 08:05:57    NaN
# 54843          56 2013-01-12 08:37:23   55.0 2013-01-12 08:37:23   56.0
# 77292         946 2013-01-12 08:50:13  946.0 2013-01-12 08:50:14  951.0
# 114021        945 2013-01-12 08:50:17  948.0 2013-01-12 08:50:17  949.0
# 146670        947 2013-01-12 08:50:20  950.0 2013-01-12 08:50:20  948.0
#
#                          time3  site4               time4  site5  \
# session_id
# 21669                      NaT    NaN                 NaT    NaN
# 54843      2013-01-12 09:07:07   55.0 2013-01-12 09:07:09    NaN
# 77292      2013-01-12 08:50:15  946.0 2013-01-12 08:50:15  946.0
# 114021     2013-01-12 08:50:18  948.0 2013-01-12 08:50:18  945.0
# 146670     2013-01-12 08:50:20  947.0 2013-01-12 08:50:21  950.0
#
#                          time5  ...               time6  site7  \
# session_id                      ...
# 21669                      NaT  ...                 NaT    NaN
# 54843                      NaT  ...                 NaT    NaN
# 77292      2013-01-12 08:50:16  ... 2013-01-12 08:50:16  948.0
# 114021     2013-01-12 08:50:18  ... 2013-01-12 08:50:18  947.0
# 146670     2013-01-12 08:50:21  ... 2013-01-12 08:50:21  946.0
#
#                          time7  site8               time8  site9  \
# session_id
# 21669                      NaT    NaN                 NaT    NaN
# 54843                      NaT    NaN                 NaT    NaN
# 77292      2013-01-12 08:50:16  784.0 2013-01-12 08:50:16  949.0
# 114021     2013-01-12 08:50:19  945.0 2013-01-12 08:50:19  946.0
# 146670     2013-01-12 08:50:21  951.0 2013-01-12 08:50:22  946.0
#
#                          time9 site10              time10 target
# session_id
# 21669                      NaT    NaN                 NaT      0
# 54843                      NaT    NaN                 NaT      0
# 77292      2013-01-12 08:50:17  946.0 2013-01-12 08:50:17      0
# 114021     2013-01-12 08:50:19  946.0 2013-01-12 08:50:20      0
# 146670     2013-01-12 08:50:22  947.0 2013-01-12 08:50:22      0
#
# [5 rows x 21 columns]

# %%
train_df.shape
# Out:
# (253561, 21)

# %%
train_df['time1']
# Out:
# session_id
# 21669    2013-01-12 08:05:57
# 54843    2013-01-12 08:37:23
# 77292    2013-01-12 08:50:13
# 114021   2013-01-12 08:50:17
# 146670   2013-01-12 08:50:20
#                  ...
# 12224    2014-04-30 23:33:48
# 164438   2014-04-30 23:34:15
# 12221    2014-04-30 23:38:08
# 156968   2014-04-30 23:38:36
# 204762   2014-04-30 23:39:53
# Name: time1, Length: 253561, dtype: datetime64[ns]

# %% [markdown]
# The training data set contains the following features:
#
# - **site1** – id of the first visited website in the session
# - **time1** – visiting time for the first website in the session
# - ...
# - **site10** – id of the tenth visited website in the session
# - **time10** – visiting time for the tenth website in the session
# - **target** – target variable, 1 for Alice's sessions, and 0 for the other users' sessions
#
# User sessions are chosen in the way that they are shorter than 30 min. long and contain no more than 10 websites. I.e. a session is considered over either if a user has visited 10 websites or if a session has lasted over 30 minutes.
#
# There are some empty values in the table, it means that some sessions contain less than ten websites. Replace empty values with 0 and change columns types to integer. Also load the websites dictionary and check how it looks like:

# %%
# Change site1, ..., site10 columns type to integer and fill NA-values with zeros
sites = ['site%s' % i for i in range(1, 11)]
train_df[sites] = train_df[sites].fillna(0).astype(np.uint16)
test_df[sites] = test_df[sites].fillna(0).astype(np.uint16)

# Load websites dictionary
with open(PATH_TO_DATA / 'site_dic.pkl', "rb") as input_file:
    site_dict = pickle.load(input_file)

# Create dataframe for the dictionary
sites_dict = pd.DataFrame(list(site_dict.keys()), index=list(site_dict.values()), 
                          columns=['site'])
print(u'Websites total:', sites_dict.shape[0])
sites_dict.head()
# Out:
# Websites total: 48371
#                                      site
# 25075              www.abmecatronique.com
# 13997                     groups.live.com
# 42436  majeureliguefootball.wordpress.com
# 30911           cdt46.media.tourinsoft.eu
# 8104                  www.hdwallpapers.eu

# %% [markdown]
# ### 2. Brief Exploratory Data Analysis

# %% [markdown]
# Before we start training models, we have to perform Exploratory Data Analysis ([EDA](https://en.wikipedia.org/wiki/Exploratory_data_analysis)). Today, we are going to perform a shorter version, but we will use other techniques as we move forward. Let's check which websites in the training data set are the most visited. As you can see, they are Google services and a bioinformatics website (a website with 'zero'-index is our missed values, just ignore it):

# %%
# Top websites in the training data set
top_sites = pd.Series(train_df[sites].values.flatten()
                     ).value_counts().sort_values(ascending=False).head(5)
print(top_sites)
sites_dict.loc[top_sites.drop(0).index]
# Out:
# 21     123776
# 0      122730
# 23      87619
# 782     77055
# 22      58258
# dtype: int64
#                 site
# 21     www.google.fr
# 23    www.google.com
# 782   annotathon.org
# 22   apis.google.com

# %% [markdown]
# ##### 1. What kind of websites does Alice visit the most?
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread __#a3_part1_fall2019__*
#
# ### - videohostings
# - social networks
# - torrent trackers
# - news

# %%
# You code here
alice_df = train_df[train_df['target']==1]

# %%
top_sites = pd.Series(alice_df[sites].values.flatten()
                     ).value_counts().sort_values(ascending=False)#.head(5)

print(top_sites)
# Out:
# 77       1382
# 80       1354
# 76       1307
# 29        897
# 21        857
#          ...
# 1206        1
# 15640       1
# 19188       1
# 1401        1
# 3159        1
# Length: 1054, dtype: int64

# %%
for i in top_sites.drop(0).index:
    print(sites_dict.loc[i])
# Out:
# site    i1.ytimg.com
# Name: 77, dtype: object
# site    s.youtube.com
# Name: 80, dtype: object
# site    www.youtube.com
# Name: 76, dtype: object
# site    www.facebook.com
# Name: 29, dtype: object
# site    www.google.fr
# Name: 21, dtype: object
# site    r4---sn-gxo5uxg-jqbe.googlevideo.com
# Name: 81, dtype: object
# site    r1---sn-gxo5uxg-jqbe.googlevideo.com
# Name: 879, dtype: object
# site    apis.google.com
# Name: 22, dtype: object
# site    s.ytimg.com
# Name: 75, dtype: object
# site    r2---sn-gxo5uxg-jqbe.googlevideo.com
# Name: 82, dtype: object
# site    www.google.com
# Name: 23, dtype: object
# site    s-static.ak.facebook.com
# Name: 35, dtype: object
# site    r3---sn-gxo5uxg-jqbe.googlevideo.com
# Name: 881, dtype: object
# site    twitter.com
# Name: 37, dtype: object
# site    static.ak.facebook.com
# Name: 33, dtype: object
# site    vk.com
# Name: 3000, dtype: object
# site    translate.google.fr
# Name: 733, dtype: object
# site    platform.twitter.com
# Name: 30, dtype: object
# site    yt3.ggpht.com
# Name: 78, dtype: object
# site    mts0.google.com
# Name: 941, dtype: object
# site    www.info-jeunes.net
# Name: 7832, dtype: object
# site    clients1.google.com
# Name: 52, dtype: object
# site    www.audienceinsights.net
# Name: 704, dtype: object
# site    www.melty.fr
# Name: 2078, dtype: object
# site    gg.google.com
# Name: 617, dtype: object
# site    plus.googleapis.com
# Name: 1057, dtype: object
# site    mts1.google.com
# Name: 942, dtype: object
# site    api.bing.com
# Name: 270, dtype: object
# site    www.dailymotion.com
# Name: 335, dtype: object
# site    youwatch.org
# Name: 12619, dtype: object
# site    deliv.leboncoin.fr
# Name: 855, dtype: object
# site    login.live.com
# Name: 3, dtype: object
# site    static.leboncoin.fr
# Name: 1514, dtype: object
# site    khms0.google.fr
# Name: 3559, dtype: object
# site    khms1.google.fr
# Name: 3560, dtype: object
# site    wwwd.caf.fr
# Name: 265, dtype: object
# site    accounts.google.com
# Name: 39, dtype: object
# site    media.melty.fr
# Name: 2077, dtype: object
# site    www.leboncoin.fr
# Name: 1515, dtype: object
# site    connect.facebook.net
# Name: 32, dtype: object
# site    clients1.google.fr
# Name: 229, dtype: object
# site    h.live.com
# Name: 14, dtype: object
# site    ajax.googleapis.com
# Name: 38, dtype: object
# site    docs.google.com
# Name: 616, dtype: object
# site    www.youtube-nocookie.com
# Name: 1307, dtype: object
# site    0.gravatar.com
# Name: 106, dtype: object
# site    maps.google.fr
# Name: 940, dtype: object
# site    1.gravatar.com
# Name: 99, dtype: object
# site    windowslive.tt.omtrdc.net
# Name: 8, dtype: object
# site    193.164.197.50
# Name: 1517, dtype: object
# site    media-1.melty.fr
# Name: 2080, dtype: object
# site    maps.googleapis.com
# Name: 896, dtype: object
# site    www.demotivateur.fr
# Name: 17283, dtype: object
# site    drive.google.com
# Name: 677, dtype: object
# site    www.caf.fr
# Name: 263, dtype: object
# site    fr.glee.wikia.com
# Name: 27307, dtype: object
# site    api.adyoulike.com
# Name: 143, dtype: object
# site    193.164.197.40
# Name: 1521, dtype: object
# site    193.164.196.40
# Name: 1519, dtype: object
# site    ad.melty.fr
# Name: 2079, dtype: object
# site    193.164.197.30
# Name: 1516, dtype: object
# site    193.164.196.60
# Name: 1518, dtype: object
# site    www.cjn.justice.gouv.fr
# Name: 25383, dtype: object
# site    193.164.196.50
# Name: 1520, dtype: object
# site    smart.allocine.fr
# Name: 5392, dtype: object
# site    193.164.197.60
# Name: 1524, dtype: object
# site    193.164.196.30
# Name: 1523, dtype: object
# site    fr.msn.com
# Name: 268, dtype: object
# site    www.banque-chalus.fr
# Name: 27189, dtype: object
# site    gdata.youtube.com
# Name: 1345, dtype: object
# site    fr.web.img1.acsta.net
# Name: 5396, dtype: object
# site    www.bing.com
# Name: 167, dtype: object
# site    khms1.google.com
# Name: 3846, dtype: object
# site    khms0.google.com
# Name: 3847, dtype: object
# site    go.trouter.io
# Name: 11, dtype: object
# site    slot1.images.wikia.nocookie.net
# Name: 2401, dtype: object
# site    dub111.mail.live.com
# Name: 6088, dtype: object
# site    dub128.mail.live.com
# Name: 51, dtype: object
# site    dub119.mail.live.com
# Name: 11241, dtype: object
# site    www.allocine.fr
# Name: 5402, dtype: object
# site    tracking.melty.fr
# Name: 2081, dtype: object
# site    s.videostep.com
# Name: 397, dtype: object
# site    i4.ytimg.com
# Name: 876, dtype: object
# site    fr.web.img2.acsta.net
# Name: 5400, dtype: object
# site    www.voyages-sncf.com
# Name: 2372, dtype: object
# site    de.tynt.com
# Name: 2271, dtype: object
# site    static1.purepeople.com
# Name: 3517, dtype: object
# site    accn.allocine.net
# Name: 5403, dtype: object
# site    syndication.twitter.com
# Name: 1919, dtype: object
# site    disqus.com
# Name: 559, dtype: object
# site    people.directory.live.com
# Name: 6, dtype: object
# site    www.purepeople.com
# Name: 4240, dtype: object
# site    img2.wikia.nocookie.net
# Name: 4693, dtype: object
# site    fr.web.img3.acsta.net
# Name: 5397, dtype: object
# site    g1ujynb3gx.b.ad6media.fr
# Name: 27172, dtype: object
# site    img1.wikia.nocookie.net
# Name: 4694, dtype: object
# site    fr.web.img4.acsta.net
# Name: 5398, dtype: object
# site    g.msn.com
# Name: 272, dtype: object
# site    www.blogger.com
# Name: 666, dtype: object
# site    asset.email-match.com
# Name: 8316, dtype: object
# site    www13.glam.com
# Name: 27339, dtype: object
# site    video.tt
# Name: 27228, dtype: object
# site    fr.web.img6.acsta.net
# Name: 5401, dtype: object
# site    www.video.tt
# Name: 27168, dtype: object
# site    www.jeux.com
# Name: 14240, dtype: object
# site    login.vk.com
# Name: 5302, dtype: object
# site    fr.web.img5.acsta.net
# Name: 5394, dtype: object
# site    h2.msn.com
# Name: 269, dtype: object
# site    cloud.cashtrafic.info
# Name: 6635, dtype: object
# site    www.wat.tv
# Name: 1324, dtype: object
# site    candidat.pole-emploi.fr
# Name: 13547, dtype: object
# site    www35.glam.com
# Name: 9783, dtype: object
# site    lh3.ggpht.com
# Name: 1441, dtype: object
# site    www.bbc.co.uk
# Name: 1455, dtype: object
# site    halc.iadvize.com
# Name: 291, dtype: object
# site    storage.live.com
# Name: 12, dtype: object
# site    mail.live.com
# Name: 4, dtype: object
# site    secure.shared.live.com
# Name: 7, dtype: object
# site    compteperso.leboncoin.fr
# Name: 1522, dtype: object
# site    pbs.twimg.com
# Name: 162, dtype: object
# site    www.kelbillet.com
# Name: 24553, dtype: object
# site    www.pole-emploi.fr
# Name: 13545, dtype: object
# site    s.aeriastatic.com
# Name: 7013, dtype: object
# site    clients6.google.com
# Name: 774, dtype: object
# site    id.google.fr
# Name: 707, dtype: object
# site    c.fr.msn.com
# Name: 271, dtype: object
# site    img4.wikia.nocookie.net
# Name: 4696, dtype: object
# site    www.indeed.fr
# Name: 3423, dtype: object
# site    rutube.ru
# Name: 6999, dtype: object
# site    reviewer.lavoixdunord.fr
# Name: 5527, dtype: object
# site    cid-ed6c3e6a5c6608a4.users.storage.live.com
# Name: 27190, dtype: object
# site    apiv1.scribblelive.com
# Name: 27221, dtype: object
# site    plugins.longtailvideo.com
# Name: 448, dtype: object
# site    lh6.ggpht.com
# Name: 1439, dtype: object
# site    www.regarder-film-gratuit.com
# Name: 27165, dtype: object
# site    glee.hypnoweb.net
# Name: 27336, dtype: object
# site    www.aeriagames.com
# Name: 7022, dtype: object
# site    i.htfacile.fr
# Name: 1315, dtype: object
# site    cackle.me
# Name: 27256, dtype: object
# site    sync.uuidcshmg.com
# Name: 233, dtype: object
# site    smart2.allocine.fr
# Name: 2214, dtype: object
# site    demotivateur.disqus.com
# Name: 18876, dtype: object
# site    static.programme-tv.net
# Name: 5879, dtype: object
# site    a69.g.akamai.net
# Name: 5391, dtype: object
# site    graph.facebook.com
# Name: 533, dtype: object
# site    www.clermont-filmfest.com
# Name: 9917, dtype: object
# site    news.bbcimg.co.uk
# Name: 1459, dtype: object
# site    www.rhonealpesjob.com
# Name: 27362, dtype: object
# site    lh4.ggpht.com
# Name: 1440, dtype: object
# site    exashare.com
# Name: 12669, dtype: object
# site    banniere.reussissonsensemble.fr
# Name: 261, dtype: object
# site    img3.wikia.nocookie.net
# Name: 4692, dtype: object
# site    hal9000.redintelligence.net
# Name: 217, dtype: object
# site    bits.wikimedia.org
# Name: 175, dtype: object
# site    ieonline.microsoft.com
# Name: 63, dtype: object
# site    g.live.com
# Name: 65, dtype: object
# site    widget.achetezfacile.com
# Name: 1312, dtype: object
# site    i2.ytimg.com
# Name: 240, dtype: object
# site    lh5.ggpht.com
# Name: 1442, dtype: object
# site    hotmail.fr
# Name: 2, dtype: object
# site    fr.ad4mat.net
# Name: 510, dtype: object
# site    www.tete-en-lair.com
# Name: 27344, dtype: object
# site    static.flickr.com
# Name: 12822, dtype: object
# site    static.videostep.com
# Name: 394, dtype: object
# site    go.disqus.com
# Name: 558, dtype: object
# site    img.youtube.com
# Name: 656, dtype: object
# site    i0.wp.com
# Name: 727, dtype: object
# site    static.weezbe.com
# Name: 27343, dtype: object
# site    l.longtailvideo.com
# Name: 644, dtype: object
# site    maps.google.com
# Name: 890, dtype: object
# site    fr.wikipedia.org
# Name: 177, dtype: object
# site    0.docs.google.com
# Name: 775, dtype: object
# site    fr-himedia.videoplaza.tv
# Name: 5301, dtype: object
# site    www.thefreecamsecret.com
# Name: 12640, dtype: object
# site    www.filmstreamingvk.ws
# Name: 19165, dtype: object
# site    0.drive.google.com
# Name: 678, dtype: object
# site    w.sharethis.com
# Name: 248, dtype: object
# site    its.tradelab.fr
# Name: 148, dtype: object
# site    api.facebook.com
# Name: 107, dtype: object
# site    youtube.fr
# Name: 2574, dtype: object
# site    seriestreaming.org
# Name: 27359, dtype: object
# site    www.express.co.uk
# Name: 27174, dtype: object
# site    login.secure.emea.msn.com
# Name: 796, dtype: object
# site    browser-update.org
# Name: 7494, dtype: object
# site    www.hebdotop.com
# Name: 3860, dtype: object
# site    js.live.net
# Name: 10, dtype: object
# site    code.jquery.com
# Name: 145, dtype: object
# site    m.ad6media.fr
# Name: 2338, dtype: object
# site    um.simpli.fi
# Name: 322, dtype: object
# site    s.srvntrk.com
# Name: 2956, dtype: object
# site    r7---sn-4g57kued.googlevideo.com
# Name: 27192, dtype: object
# site    regie.espace-plus.net
# Name: 3156, dtype: object
# site    static.bbci.co.uk
# Name: 1457, dtype: object
# site    rp.gwallet.com
# Name: 319, dtype: object
# site    r1---sn-cg07luel.googlevideo.com
# Name: 18611, dtype: object
# site    www.jobisjob.fr
# Name: 3740, dtype: object
# site    r8---sn-4g57kues.googlevideo.com
# Name: 27194, dtype: object
# site    mm.eulerian.net
# Name: 392, dtype: object
# site    www.googleapis.com
# Name: 752, dtype: object
# site    foiredustreaming.com
# Name: 27261, dtype: object
# site    www.a2micile.com
# Name: 27229, dtype: object
# site    r3---sn-4g57kued.googlevideo.com
# Name: 27193, dtype: object
# site    auto.img.v4.skyrock.net
# Name: 4954, dtype: object
# site    rubicon-match.dotomi.com
# Name: 324, dtype: object
# site    glee.wikia.com
# Name: 27306, dtype: object
# site    www2.leboncoin.fr
# Name: 5217, dtype: object
# site    fpdownload2.macromedia.com
# Name: 1, dtype: object
# site    www.programme-tv.net
# Name: 5878, dtype: object
# site    r2---sn-aigllm7e.googlevideo.com
# Name: 27296, dtype: object
# site    r2---fra07t13.googlevideo.com
# Name: 27195, dtype: object
# site    lp.longtailvideo.com
# Name: 486, dtype: object
# site    cid-4390f92c7906cc9c.users.storage.live.com
# Name: 27269, dtype: object
# site    s.radio-canada.ca
# Name: 3142, dtype: object
# site    www35t.glam.com
# Name: 9785, dtype: object
# site    i3.ytimg.com
# Name: 873, dtype: object
# site    meta.wikimedia.org
# Name: 178, dtype: object
# site    streamzzz.com
# Name: 27255, dtype: object
# site    www.hellopro.fr
# Name: 13085, dtype: object
# site    livepassdl.conviva.com
# Name: 1074, dtype: object
# site    www.auvergne.afpa.fr
# Name: 27235, dtype: object
# site    full-stream.net
# Name: 19196, dtype: object
# site    slot1.images3.wikia.nocookie.net
# Name: 2512, dtype: object
# site    my.cloudify.cc
# Name: 12622, dtype: object
# site    www.brgm.fr
# Name: 10687, dtype: object
# site    www.ultimedia.com
# Name: 836, dtype: object
# site    spring-breakers.wikia.com
# Name: 27332, dtype: object
# site    1.bp.blogspot.com
# Name: 367, dtype: object
# site    jooble-fr.com
# Name: 5238, dtype: object
# site    www.monalbumphoto.fr
# Name: 27298, dtype: object
# site    kwebstat.videostep.com
# Name: 2580, dtype: object
# site    2.bp.blogspot.com
# Name: 655, dtype: object
# site    static1.videostep.com
# Name: 5532, dtype: object
# site    tc.airfrance.com
# Name: 2491, dtype: object
# site    match.rtbidder.net
# Name: 156, dtype: object
# site    seweb.videostep.com
# Name: 5531, dtype: object
# site    medias.weezbe.com
# Name: 27345, dtype: object
# site    slot1.images1.wikia.nocookie.net
# Name: 2400, dtype: object
# site    images.wikia.com
# Name: 7544, dtype: object
# site    www.jeux.fr
# Name: 14310, dtype: object
# site    h0io25vbe3.s.ad6media.fr
# Name: 27338, dtype: object
# site    choices.truste.com
# Name: 350, dtype: object
# site    emp.bbci.co.uk
# Name: 1463, dtype: object
# site    ad.publicidees.com
# Name: 220, dtype: object
# site    spoilertv.springboardplatform.com
# Name: 27289, dtype: object
# site    www.lacafrecrute.fr
# Name: 27276, dtype: object
# site    cache.20minutes.fr
# Name: 2589, dtype: object
# site    mcetv.fr
# Name: 27348, dtype: object
# site    probe.cedexis.org
# Name: 400, dtype: object
# site    test-orientation.studyrama.com
# Name: 27277, dtype: object
# site    www.horairetrain.net
# Name: 27311, dtype: object
# site    img.over-blog.com
# Name: 609, dtype: object
# site    admin.brightcove.com
# Name: 454, dtype: object
# site    653.studyrama.com
# Name: 1277, dtype: object
# site    ce.lijit.com
# Name: 157, dtype: object
# site    www.exashare.com
# Name: 27167, dtype: object
# site    3.bp.blogspot.com
# Name: 648, dtype: object
# site    www.live.bbc.co.uk
# Name: 1456, dtype: object
# site    graphics8.nytimes.com
# Name: 24156, dtype: object
# site    slot1.images2.wikia.nocookie.net
# Name: 2406, dtype: object
# site    s3.amazonaws.com
# Name: 87, dtype: object
# site    sa.bbc.com
# Name: 1462, dtype: object
# site    www.ajoutezvotresite.com
# Name: 19166, dtype: object
# site    zupimages.net
# Name: 27271, dtype: object
# site    atout.email-match.com
# Name: 8315, dtype: object
# site    images.allocine.fr
# Name: 5399, dtype: object
# site    www.reddit.com
# Name: 551, dtype: object
# site    www.springboardplatform.com
# Name: 16486, dtype: object
# site    img1.blogblog.com
# Name: 661, dtype: object
# site    www.blastr.com
# Name: 25904, dtype: object
# site    static.tumblr.com
# Name: 1677, dtype: object
# site    www.congres-medical.com
# Name: 27202, dtype: object
# site    vodlocker.com
# Name: 27381, dtype: object
# site    www.90c.fr
# Name: 27389, dtype: object
# site    04.wir.skyrock.net
# Name: 19922, dtype: object
# site    assets.tumblr.com
# Name: 4369, dtype: object
# site    regarder-film-gratuit.com
# Name: 27166, dtype: object
# site    plus.lefigaro.fr
# Name: 503, dtype: object
# site    img1.video.s-msn.com
# Name: 790, dtype: object
# site    pixel.alephd.com
# Name: 140, dtype: object
# site    mts3.google.com
# Name: 3848, dtype: object
# site    tru.am
# Name: 11812, dtype: object
# site    www.anonymousdmp.com
# Name: 703, dtype: object
# site    kweb.videostep.com
# Name: 395, dtype: object
# site    wwwstats.brgm.fr
# Name: 10685, dtype: object
# site    wwwimages.adobe.com
# Name: 388, dtype: object
# site    mt0.googleapis.com
# Name: 1994, dtype: object
# site    1.docs.google.com
# Name: 1274, dtype: object
# site    optim.dekalee.fr
# Name: 3241, dtype: object
# site    www.maxitoys.fr
# Name: 13604, dtype: object
# site    google.fr
# Name: 20, dtype: object
# site    4.bp.blogspot.com
# Name: 652, dtype: object
# site    www.meltyfashion.fr
# Name: 27300, dtype: object
# site    braindamaged.fr
# Name: 27312, dtype: object
# site    vkstreaming-series.com
# Name: 27320, dtype: object
# site    www.regles-de-jeux.com
# Name: 27241, dtype: object
# site    www.beepjob.com
# Name: 13028, dtype: object
# site    www.yeslibertin.com
# Name: 19187, dtype: object
# site    mts1.googleapis.com
# Name: 5644, dtype: object
# site    d1zdqwv4o6pivl.cloudfront.net
# Name: 2650, dtype: object
# site    network.aufeminin.com
# Name: 5499, dtype: object
# site    www.jobijoba.com
# Name: 5990, dtype: object
# site    r3---sn-4g57kuer.googlevideo.com
# Name: 27197, dtype: object
# site    b12.myspace.com
# Name: 716, dtype: object
# site    lacapoeira.free.fr
# Name: 27201, dtype: object
# site    open.bbci.co.uk
# Name: 1467, dtype: object
# site    fdata.over-blog.net
# Name: 681, dtype: object
# site    deliv.bayard-pub.com
# Name: 5442, dtype: object
# site    www.qapa.fr
# Name: 13930, dtype: object
# site    pagesmed-assets.s3.amazonaws.com
# Name: 27358, dtype: object
# site    login.wikimedia.org
# Name: 176, dtype: object
# site    open.live.bbc.co.uk
# Name: 1465, dtype: object
# site    www.casier-judiciaire.org
# Name: 27367, dtype: object
# site    www.radio-canada.ca
# Name: 3150, dtype: object
# site    www.activistpost.com
# Name: 27184, dtype: object
# site    t.voyages-sncf.com
# Name: 3854, dtype: object
# site    www.starstable.com
# Name: 12623, dtype: object
# site    www.adobe.com
# Name: 389, dtype: object
# site    www.meltyfood.fr
# Name: 3471, dtype: object
# site    dev.wikia.com
# Name: 2514, dtype: object
# site    mts0.googleapis.com
# Name: 5266, dtype: object
# site    mts2.google.com
# Name: 3849, dtype: object
# site    andromeda5.com
# Name: 27250, dtype: object
# site    www.viedemerde.fr
# Name: 3239, dtype: object
# site    www.staragora.com
# Name: 5518, dtype: object
# site    inskin01.wt-eu02.net
# Name: 22410, dtype: object
# site    mt1.googleapis.com
# Name: 1995, dtype: object
# site    www.linkedin.com
# Name: 117, dtype: object
# site    static77.jobisjob.com
# Name: 3739, dtype: object
# site    krxd.nexac.com
# Name: 2410, dtype: object
# site    abc.www.express.co.uk
# Name: 27176, dtype: object
# site    player.vimeo.com
# Name: 170, dtype: object
# site    unlni1eiy0.s.ad6media.fr
# Name: 27264, dtype: object
# site    news.bbc.co.uk
# Name: 1464, dtype: object
# site    betacie.cachefly.net
# Name: 3240, dtype: object
# site    static.v5.skyrock.net
# Name: 14906, dtype: object
# site    r8---sn-4g57kue6.googlevideo.com
# Name: 27198, dtype: object
# site    pixel2368.everesttech.net
# Name: 152, dtype: object
# site    31.media.tumblr.com
# Name: 4366, dtype: object
# site    static.mediabong.com
# Name: 457, dtype: object
# site    static.ad4mat.net
# Name: 515, dtype: object
# site    a.nonstoppartner.net
# Name: 563, dtype: object
# site    imworld.aufeminin.com
# Name: 2094, dtype: object
# site    www.purefans.com
# Name: 27342, dtype: object
# site    api.skype.com
# Name: 16, dtype: object
# site    www.vends-ta-culotte.com
# Name: 27273, dtype: object
# site    a405.idata.over-blog.com
# Name: 700, dtype: object
# site    accounts.google.fr
# Name: 679, dtype: object
# site    platform.linkedin.com
# Name: 516, dtype: object
# site    megaphone-sonorisation-portable.com
# Name: 27247, dtype: object
# site    pings.conviva.com
# Name: 134, dtype: object
# site    d36xtkk24g8jdx.cloudfront.net
# Name: 1946, dtype: object
# site    www.melty.es
# Name: 2074, dtype: object
# site    adventori.com
# Name: 161, dtype: object
# site    www.geoforum.fr
# Name: 9712, dtype: object
# site    referentiel.nouvelobs.com
# Name: 139, dtype: object
# site    a.ad-sys.com
# Name: 2856, dtype: object
# site    accounts.youtube.com
# Name: 676, dtype: object
# site    leplus.nouvelobs.com
# Name: 3775, dtype: object
# site    a248.e.akamai.net
# Name: 1092, dtype: object
# site    www.magasins-u.com
# Name: 27380, dtype: object
# site    xof2q195ix.s.ad6media.fr
# Name: 27279, dtype: object
# site    cdnjs.cloudflare.com
# Name: 144, dtype: object
# site    proxy-blu-people.directory.live.com
# Name: 1922, dtype: object
# site    fidelite-programme-voyageur.sncf.com
# Name: 14940, dtype: object
# site    api.spilgames.com
# Name: 3274, dtype: object
# site    img.123rf.net
# Name: 3341, dtype: object
# site    www.lacoope.org
# Name: 19634, dtype: object
# site    www.melty.it
# Name: 2076, dtype: object
# site    r8---sn-4g57kuek.googlevideo.com
# Name: 27196, dtype: object
# site    d3fqh47ho4rujh.cloudfront.net
# Name: 1569, dtype: object
# site    ea.numericable.fr
# Name: 341, dtype: object
# site    geo0.ggpht.com
# Name: 5262, dtype: object
# site    p.sfx.ms
# Name: 18, dtype: object
# site    api.web-editions.fr
# Name: 27368, dtype: object
# site    wtpn.twenga.fr
# Name: 317, dtype: object
# site    rbp.mxptint.net
# Name: 323, dtype: object
# site    www.rhonealpes.fr
# Name: 27211, dtype: object
# site    danstonchat.com
# Name: 18727, dtype: object
# site    c1.adform.net
# Name: 321, dtype: object
# site    nayariverasource.com
# Name: 27351, dtype: object
# site    static.qapa.fr
# Name: 13931, dtype: object
# site    footage.framepool.com
# Name: 27224, dtype: object
# site    s.wat.tv
# Name: 1326, dtype: object
# site    www.lefigaro.fr
# Name: 500, dtype: object
# site    dc46.s233.meetrics.net
# Name: 1403, dtype: object
# site    www.lepoint.fr
# Name: 386, dtype: object
# site    idata.over-blog.com
# Name: 684, dtype: object
# site    dub111.afx.ms
# Name: 9394, dtype: object
# site    www.contrepoints.org
# Name: 6614, dtype: object
# site    cimg.leguide.com
# Name: 141, dtype: object
# site    player.mediabong.com
# Name: 390, dtype: object
# site    www.vdm.fr
# Name: 16814, dtype: object
# site    cdns.gigya.com
# Name: 355, dtype: object
# site    a395.idata.over-blog.com
# Name: 688, dtype: object
# site    style2.ad6.fr
# Name: 42, dtype: object
# site    www.mail.live.com
# Name: 794, dtype: object
# site    y.one.impact-ad.jp
# Name: 159, dtype: object
# site    79.98.96.110
# Name: 27263, dtype: object
# site    edge.sharethis.com
# Name: 527, dtype: object
# site    mt.google.com
# Name: 3170, dtype: object
# site    gravatar.com
# Name: 4238, dtype: object
# site    c.msn.com
# Name: 1998, dtype: object
# site    a402.idata.over-blog.com
# Name: 691, dtype: object
# site    sam.zebestof.com
# Name: 2413, dtype: object
# site    u.videostep.com
# Name: 396, dtype: object
# site    eulerian.canal-plus.com
# Name: 131, dtype: object
# site    www.actu-environnement.com
# Name: 12748, dtype: object
# site    r5---sn-cg07luez.googlevideo.com
# Name: 13031, dtype: object
# site    pr.ybp.yahoo.com
# Name: 325, dtype: object
# site    fr.123rf.com
# Name: 1573, dtype: object
# site    www.r-c.ca
# Name: 21551, dtype: object
# site    www.cgrcinemas.fr
# Name: 21104, dtype: object
# site    links.kelbillet.com
# Name: 24554, dtype: object
# site    r7---sn-cg07lued.googlevideo.com
# Name: 12121, dtype: object
# site    i.ytimg.com
# Name: 837, dtype: object
# site    www.tuxboard.com
# Name: 2045, dtype: object
# site    www.tumblr.com
# Name: 4368, dtype: object
# site    r8---sn-cg07lue6.googlevideo.com
# Name: 14616, dtype: object
# site    cdn24.ne.be
# Name: 5528, dtype: object
# site    static.bbc.co.uk
# Name: 1466, dtype: object
# site    yui.yahooapis.com
# Name: 338, dtype: object
# site    www.nytimes.com
# Name: 25703, dtype: object
# site    r8---sn-4g57kuel.googlevideo.com
# Name: 27199, dtype: object
# site    sfr.cedexis.com
# Name: 2090, dtype: object
# site    www.rcmp-grc.gc.ca
# Name: 27365, dtype: object
# site    r7---sn-4g57kuer.googlevideo.com
# Name: 27191, dtype: object
# site    hub.video.msn.com
# Name: 792, dtype: object
# site    www.billetreduc.com
# Name: 27354, dtype: object
# site    static.koramgame.com
# Name: 12625, dtype: object
# site    cntr.adrcntr.com
# Name: 273, dtype: object
# site    apnx-match.dotomi.com
# Name: 262, dtype: object
# site    a401.idata.over-blog.com
# Name: 685, dtype: object
# site    a403.idata.over-blog.com
# Name: 697, dtype: object
# site    streaming.springboardvideo.com
# Name: 27290, dtype: object
# site    www.emploi-environnement.com
# Name: 12747, dtype: object
# site    foglio.basilic.io
# Name: 461, dtype: object
# site    byfiles.storage.msn.com
# Name: 1200, dtype: object
# site    logs.spilgames.com
# Name: 3272, dtype: object
# site    widget.uservoice.com
# Name: 1262, dtype: object
# site    a397.idata.over-blog.com
# Name: 607, dtype: object
# site    i.videostep.com
# Name: 5533, dtype: object
# site    r1---sn-4g57kuer.googlevideo.com
# Name: 27200, dtype: object
# site    mw2.google.com
# Name: 797, dtype: object
# site    www.mes-meilleurs-films.fr
# Name: 12638, dtype: object
# site    a407.idata.over-blog.com
# Name: 690, dtype: object
# site    www.sefaireaider.com
# Name: 27308, dtype: object
# site    broadcast.piximedia.fr
# Name: 256, dtype: object
# site    a133.idata.over-blog.com
# Name: 702, dtype: object
# site    asset0.serieweb.com
# Name: 27375, dtype: object
# site    static.xs-software.com
# Name: 27251, dtype: object
# site    a136.idata.over-blog.com
# Name: 692, dtype: object
# site    hit.leboncoin.fr
# Name: 13572, dtype: object
# site    level3.cedexis.com
# Name: 756, dtype: object
# site    www.blogblog.com
# Name: 658, dtype: object
# site    r4---sn-cg07lues.googlevideo.com
# Name: 8719, dtype: object
# site    calotag.com
# Name: 2458, dtype: object
# site    a137.idata.over-blog.com
# Name: 606, dtype: object
# site    www.serieweb.com
# Name: 27377, dtype: object
# site    api.fidji.lefigaro.fr
# Name: 501, dtype: object
# site    endor.mediabong.com
# Name: 843, dtype: object
# site    media.csf.gouv.qc.ca
# Name: 27222, dtype: object
# site    clients2.google.com
# Name: 814, dtype: object
# site    feedback20.s3.amazonaws.com
# Name: 16522, dtype: object
# site    a400.idata.over-blog.com
# Name: 687, dtype: object
# site    fr.anno-online.com
# Name: 12628, dtype: object
# site    fby.s3.amazonaws.com
# Name: 5395, dtype: object
# site    evt.adrcntr.com
# Name: 274, dtype: object
# site    a404.idata.over-blog.com
# Name: 693, dtype: object
# site    glee-france.fr
# Name: 27340, dtype: object
# site    a392.idata.over-blog.com
# Name: 689, dtype: object
# site    h.bing.com
# Name: 54, dtype: object
# site    s0.wat.fr
# Name: 9800, dtype: object
# site    premium.hi-mediaserver.com
# Name: 182, dtype: object
# site    assets4.lefigaro.fr
# Name: 506, dtype: object
# site    offre.pole-emploi.fr
# Name: 13546, dtype: object
# site    images.orangepublicite.fr
# Name: 393, dtype: object
# site    fr.conv.indeed.com
# Name: 5668, dtype: object
# site    www.lesobservateurs.ch
# Name: 27239, dtype: object
# site    fr.mlgame.org
# Name: 27316, dtype: object
# site    fbstatic-a.akamaihd.net
# Name: 1162, dtype: object
# site    www.be2.fr
# Name: 7417, dtype: object
# site    comptepro.leboncoin.fr
# Name: 18642, dtype: object
# site    retargeting.veoxa.com
# Name: 936, dtype: object
# site    ci.impdesk.com
# Name: 2733, dtype: object
# site    www.schaerbeek.be
# Name: 27366, dtype: object
# site    agora.qc.ca
# Name: 1848, dtype: object
# site    prod.registrar.skype.com
# Name: 15, dtype: object
# site    iad.rackspace.bench.cedexis.com
# Name: 3625, dtype: object
# site    us.cdn2.123rf.com
# Name: 1576, dtype: object
# site    www.aufeminin.com
# Name: 5498, dtype: object
# site    assets5.lefigaro.fr
# Name: 502, dtype: object
# site    mfr.meteofrance.com
# Name: 2213, dtype: object
# site    media.meltyfood.fr
# Name: 3470, dtype: object
# site    i2.wp.com
# Name: 612, dtype: object
# site    videosfr.s3.amazonaws.com
# Name: 125, dtype: object
# site    www.pagesmed.com
# Name: 27357, dtype: object
# site    promo.maxidivx.com
# Name: 12614, dtype: object
# site    media.espace-plus.net
# Name: 3158, dtype: object
# site    cdnss.freepik.com
# Name: 3534, dtype: object
# site    img2.video.s-msn.com
# Name: 791, dtype: object
# site    www.musicmove-store.com
# Name: 27245, dtype: object
# site    asset2.serieweb.com
# Name: 27373, dtype: object
# site    static3.fr.anno-online.com
# Name: 12629, dtype: object
# site    www.neatorama.com
# Name: 27178, dtype: object
# site    js.nyt.com
# Name: 25704, dtype: object
# site    naruto.games.la
# Name: 27305, dtype: object
# site    img2.blogblog.com
# Name: 660, dtype: object
# site    media.goodgamestudios.com
# Name: 14963, dtype: object
# site    slot1.images4.wikia.nocookie.net
# Name: 2405, dtype: object
# site    en.wikipedia.org
# Name: 343, dtype: object
# site    livestats.fr
# Name: 7009, dtype: object
# site    a54.idata.over-blog.com
# Name: 696, dtype: object
# site    media.prizee.com
# Name: 14245, dtype: object
# site    s.wat.fr
# Name: 9799, dtype: object
# site    assets.ebz.io
# Name: 1410, dtype: object
# site    node1.bbcimg.co.uk
# Name: 1458, dtype: object
# site    r4---sn-cg07luel.googlevideo.com
# Name: 3586, dtype: object
# site    cs.specificclick.net
# Name: 751, dtype: object
# site    asset3.serieweb.com
# Name: 27374, dtype: object
# site    www.studyrama.com
# Name: 11361, dtype: object
# site    js.sddan.com
# Name: 1444, dtype: object
# site    listener.ezakus.net
# Name: 391, dtype: object
# site    brgm-recrute.talent-soft.com
# Name: 27231, dtype: object
# site    farm8.static.flickr.com
# Name: 11525, dtype: object
# site    www.presentezvous.com
# Name: 27364, dtype: object
# site    www.actu-money.com
# Name: 12426, dtype: object
# site    asset1.serieweb.com
# Name: 27376, dtype: object
# site    static.mylittlefarmies.de
# Name: 19201, dtype: object
# site    cshoppingbox.partner.leguide.com
# Name: 142, dtype: object
# site    assets-pub.lefigaro.fr
# Name: 511, dtype: object
# site    s.kau.li
# Name: 158, dtype: object
# site    thumb10.shutterstock.com
# Name: 9302, dtype: object
# site    static.jobrapido.com
# Name: 13933, dtype: object
# site    hiroservers.appspot.com
# Name: 9871, dtype: object
# site    ia.nspmotion.com
# Name: 1915, dtype: object
# site    actudesfinances.info
# Name: 27278, dtype: object
# site    msn.careerbuilder.fr
# Name: 27230, dtype: object
# site    zopim.com
# Name: 27246, dtype: object
# site    media.meltyfashion.fr
# Name: 21352, dtype: object
# site    cnn.disqus.com
# Name: 3111, dtype: object
# site    static1.shopoon.fr
# Name: 387, dtype: object
# site    www.syfy.com
# Name: 12187, dtype: object
# site    wd.sharethis.com
# Name: 1278, dtype: object
# site    wawa-series.com
# Name: 27280, dtype: object
# site    ada.brucelead.com
# Name: 23207, dtype: object
# site    www.get-the-look.fr
# Name: 4241, dtype: object
# site    img.media-rendering1.com
# Name: 27248, dtype: object
# site    static.neatoshop.com
# Name: 27180, dtype: object
# site    www.njobs.fr
# Name: 27232, dtype: object
# site    www.ohmymag.com
# Name: 27216, dtype: object
# site    storage.googleapis.com
# Name: 2396, dtype: object
# site    p7.storage.canalblog.com
# Name: 3280, dtype: object
# site    storage.canalblog.com
# Name: 3212, dtype: object
# site    ibeu2.mookie1.com
# Name: 3776, dtype: object
# site    www.ined.fr
# Name: 13429, dtype: object
# site    photos.cityvox.com
# Name: 3901, dtype: object
# site    support.google.com
# Name: 2397, dtype: object
# site    www.secours-catholique.org
# Name: 27233, dtype: object
# site    comments.us1.gigya.com
# Name: 12103, dtype: object
# site    med.wat.tv
# Name: 5181, dtype: object
# site    cinefac.o2switch.net
# Name: 27253, dtype: object
# site    img.src.ca
# Name: 9587, dtype: object
# site    www.hot-live-chat.com
# Name: 27173, dtype: object
# site    sitelife.radio-canada.ca
# Name: 27220, dtype: object
# site    media.cyrillus.fr
# Name: 519, dtype: object
# site    limelight.cedexis.com
# Name: 473, dtype: object
# site    s1.karafun.com
# Name: 27242, dtype: object
# site    www.astuce2014.com
# Name: 27258, dtype: object
# site    cloudfront.cedexis.com
# Name: 399, dtype: object
# site    n.dyntrk.com
# Name: 2296, dtype: object
# site    word-view.officeapps.live.com
# Name: 169, dtype: object
# site    up.bidsystem.com
# Name: 27322, dtype: object
# site    annonces-emploi.vivastreet.com
# Name: 5994, dtype: object
# site    pic.rutube.ru
# Name: 7060, dtype: object
# site    r8---sn-cg07lued.googlevideo.com
# Name: 24573, dtype: object
# site    hotmailproxy.fr.msn.com
# Name: 9651, dtype: object
# site    assets.zendesk.com
# Name: 2249, dtype: object
# site    liftium.wikia.com
# Name: 2409, dtype: object
# site    badges.instagram.com
# Name: 1944, dtype: object
# site    videoplayer.ru
# Name: 19134, dtype: object
# site    culture-et-debats.over-blog.com
# Name: 13344, dtype: object
# site    p8.storage.canalblog.com
# Name: 3279, dtype: object
# site    sc.wawa-series.com
# Name: 27281, dtype: object
# site    lp.jerencontre.fr
# Name: 27265, dtype: object
# site    bonplan1.com
# Name: 27249, dtype: object
# site    go.microsoft.com
# Name: 66, dtype: object
# site    www.melty.de
# Name: 2786, dtype: object
# site    s.ixiaa.com
# Name: 4416, dtype: object
# site    edition.cnn.com
# Name: 3109, dtype: object
# site    spotlights.wikia.net
# Name: 13135, dtype: object
# site    facebook.madmoo.com
# Name: 27319, dtype: object
# site    dsp.active-agent.com
# Name: 1355, dtype: object
# site    player.vimple.ru
# Name: 19132, dtype: object
# site    i10.twenga.com
# Name: 320, dtype: object
# site    www.glucoburner.com
# Name: 17139, dtype: object
# site    r6---sn-cg07luer.googlevideo.com
# Name: 2575, dtype: object
# site    a141.idata.over-blog.com
# Name: 699, dtype: object
# site    cid-9ab66031678d7800.users.storage.live.com
# Name: 27270, dtype: object
# site    om.forgeofempires.com
# Name: 2465, dtype: object
# site    api.choicestream.com
# Name: 4697, dtype: object
# site    toutesunart.tumblr.com
# Name: 27333, dtype: object
# site    femmesdispo.com
# Name: 12621, dtype: object
# site    dtm.footlocker.com
# Name: 2615, dtype: object
# site    media.hypnoweb.net
# Name: 27335, dtype: object
# site    cip.gagnoo.com
# Name: 1116, dtype: object
# site    x2.vindicosuite.com
# Name: 155, dtype: object
# site    sqm.telemetry.microsoft.com
# Name: 3557, dtype: object
# site    media-social.s-msn.com
# Name: 4185, dtype: object
# site    p.typekit.net
# Name: 85, dtype: object
# site    calendrier.voyages-sncf.com
# Name: 24841, dtype: object
# site    us.cdn3.123rf.com
# Name: 1578, dtype: object
# site    a142.idata.over-blog.com
# Name: 686, dtype: object
# site    p4.storage.canalblog.com
# Name: 3275, dtype: object
# site    ajax.cloudflare.com
# Name: 549, dtype: object
# site    assets.pinterest.com
# Name: 352, dtype: object
# site    kingsandlegends.com
# Name: 19183, dtype: object
# site    a398.idata.over-blog.com
# Name: 701, dtype: object
# site    www.chronometre-en-ligne.com
# Name: 14817, dtype: object
# site    thumb15.shutterstock.com
# Name: 27207, dtype: object
# site    www.123rf.com
# Name: 1577, dtype: object
# site    playlists.bbc.co.uk
# Name: 23049, dtype: object
# site    braindamagedfr.disqus.com
# Name: 27313, dtype: object
# site    fr.aion.gameforge.com
# Name: 15639, dtype: object
# site    p1.storage.canalblog.com
# Name: 3281, dtype: object
# site    blog.topheman.com
# Name: 27346, dtype: object
# site    cdn-files.deezer.com
# Name: 1387, dtype: object
# site    socialcam.com
# Name: 27325, dtype: object
# site    mrpyros.over-blog.com
# Name: 27347, dtype: object
# site    r3---sn-cg07luel.googlevideo.com
# Name: 21263, dtype: object
# site    admaym.com
# Name: 160, dtype: object
# site    cpm1.affiz.net
# Name: 3268, dtype: object
# site    offre.jobisjob.fr
# Name: 13675, dtype: object
# site    boutique-online.orange.fr
# Name: 1349, dtype: object
# site    www.allsoftdll.com
# Name: 12620, dtype: object
# site    www.groupon.fr
# Name: 342, dtype: object
# site    r.kelkoo.com
# Name: 2587, dtype: object
# site    lp.koramgame.com
# Name: 12624, dtype: object
# site    s0.wp.com
# Name: 102, dtype: object
# site    www.melty.com.br
# Name: 2075, dtype: object
# site    img.icbdr.com
# Name: 17476, dtype: object
# site    www2.glam.com
# Name: 9787, dtype: object
# site    maps-api-ssl.google.com
# Name: 3876, dtype: object
# site    login.skype.com
# Name: 64, dtype: object
# site    www.allgoob.com
# Name: 5991, dtype: object
# site    blufiles.storage.msn.com
# Name: 13, dtype: object
# site    gadcreatives.glam.com
# Name: 10941, dtype: object
# site    www.squid-cache.org
# Name: 45, dtype: object
# site    gcm.ezakus.net
# Name: 14241, dtype: object
# site    p5.storage.canalblog.com
# Name: 3278, dtype: object
# site    d1r2y962f8isle.cloudfront.net
# Name: 4979, dtype: object
# site    fr-fr.facebook.com
# Name: 173, dtype: object
# site    shell.windows.com
# Name: 801, dtype: object
# site    ichef.bbci.co.uk
# Name: 1460, dtype: object
# site    s233.meetrics.net
# Name: 1402, dtype: object
# site    i1.nyt.com
# Name: 25705, dtype: object
# site    pool-eu-ie.creative-serving.com
# Name: 1049, dtype: object
# site    software.hiro.tv
# Name: 9870, dtype: object
# site    www.regionsjob.com
# Name: 5672, dtype: object
# site    fastly.cedexis.com
# Name: 3976, dtype: object
# site    46.105.57.81
# Name: 27282, dtype: object
# site    fr.jobrapido.com
# Name: 13932, dtype: object
# site    www.karafun.fr
# Name: 27243, dtype: object
# site    www.nbcudigitaladops.com
# Name: 12188, dtype: object
# site    origin-www.20minutes.fr
# Name: 2595, dtype: object
# site    sante.clermont-universite.fr
# Name: 7666, dtype: object
# site    dtm.ccs.com
# Name: 2060, dtype: object
# site    jeuxstrategieter.free.fr
# Name: 11394, dtype: object
# site    typeface.nytimes.com
# Name: 25930, dtype: object
# site    www.ted.com
# Name: 1468, dtype: object
# site    api.toptenreviews.com
# Name: 27181, dtype: object
# site    akvideo.aufeminin.com
# Name: 4832, dtype: object
# site    app.be2.fr
# Name: 19189, dtype: object
# site    www.insee.fr
# Name: 7789, dtype: object
# site    fileserver.glam.com
# Name: 9786, dtype: object
# site    fastlydsa.bench.cedexis.com
# Name: 450, dtype: object
# site    cms.abmr.net
# Name: 359, dtype: object
# site    i1.wp.com
# Name: 728, dtype: object
# site    adm.fwmrm.net
# Name: 3369, dtype: object
# site    static.freepik.com
# Name: 3542, dtype: object
# site    fr.freepik.com
# Name: 3535, dtype: object
# site    cdn0.bnmla.com
# Name: 27388, dtype: object
# site    us.cdn1.123rf.com
# Name: 1575, dtype: object
# site    traquee.com
# Name: 6636, dtype: object
# site    s20.postimg.org
# Name: 27259, dtype: object
# site    ver-adt.vindicosuite.com
# Name: 714, dtype: object
# site    res1.windows.microsoft.com
# Name: 70, dtype: object
# site    video.msn.com
# Name: 793, dtype: object
# site    bdm.programme-tv.net
# Name: 5880, dtype: object
# site    instagram.com
# Name: 2654, dtype: object
# site    us.cdn4.123rf.com
# Name: 1574, dtype: object
# site    chart.apis.google.com
# Name: 1924, dtype: object
# site    cdn1.freepik.com
# Name: 3540, dtype: object
# site    log.wat.tv
# Name: 5131, dtype: object
# site    ressources.regionsjob.com
# Name: 5670, dtype: object
# site    img.tuxboard.com
# Name: 3703, dtype: object
# site    www.tout-sur-le-web.com
# Name: 19167, dtype: object
# site    sondage.som.ca
# Name: 27223, dtype: object
# site    seal-chicago.bbb.org
# Name: 1572, dtype: object
# site    www.vos-droits.justice.gouv.fr
# Name: 27371, dtype: object
# site    cbks3.google.com
# Name: 6006, dtype: object
# site    eu1.swbdds.com
# Name: 5335, dtype: object
# site    i.imgur.com
# Name: 3012, dtype: object
# site    secure.gravatar.com
# Name: 1029, dtype: object
# site    divertissement.orangeportails.net
# Name: 3900, dtype: object
# site    s0.vimple.ru
# Name: 19135, dtype: object
# site    cyrillus.commander1.com
# Name: 517, dtype: object
# site    3c41ddc0.se
# Name: 27266, dtype: object
# site    stats.xs-software.com
# Name: 27252, dtype: object
# site    www.mylittlefarmies.fr
# Name: 19200, dtype: object
# site    www.femme-cougar.tv
# Name: 19136, dtype: object
# site    www.toutmoinscher.com
# Name: 27287, dtype: object
# site    dm2304files.storage.live.com
# Name: 2631, dtype: object
# site    www.deezer.com
# Name: 1386, dtype: object
# site    js.microsoft.com
# Name: 71, dtype: object
# site    track.games.la
# Name: 27304, dtype: object
# site    sdc2.radio-canada.ca
# Name: 3147, dtype: object
# site    www.01-fond-ecran.com
# Name: 27208, dtype: object
# site    2.drive.google.com
# Name: 3480, dtype: object
# site    www.uaredesign.com
# Name: 2628, dtype: object
# site    badge.stumbleupon.com
# Name: 565, dtype: object
# site    ie-games.com
# Name: 27383, dtype: object
# site    www.financialsmartbot.com
# Name: 27268, dtype: object
# site    wount.com
# Name: 27284, dtype: object
# site    static.canalblog.com
# Name: 3211, dtype: object
# site    static.viva-images.com
# Name: 5995, dtype: object
# site    springbreakersfilm.tumblr.com
# Name: 27324, dtype: object
# site    www.infidelia.com
# Name: 27372, dtype: object
# site    api.allocine.fr
# Name: 20244, dtype: object
# site    p3.storage.canalblog.com
# Name: 1826, dtype: object
# site    static.ndsstatic.com
# Name: 27217, dtype: object
# site    media.mtvnservices.com
# Name: 9702, dtype: object
# site    cdn3.freepik.com
# Name: 3539, dtype: object
# site    cache-02.cleanprint.net
# Name: 3110, dtype: object
# site    ie7-js.googlecode.com
# Name: 7216, dtype: object
# site    ftn.fortuneo.fr
# Name: 2542, dtype: object
# site    www.player.previewnetworks.com
# Name: 15159, dtype: object
# site    www.freefilmshd.com
# Name: 27226, dtype: object
# site    admin.wbusiness.fr
# Name: 7852, dtype: object
# site    p0.storage.canalblog.com
# Name: 3285, dtype: object
# site    zfacts.com
# Name: 27188, dtype: object
# site    api.radio-canada.ca
# Name: 21550, dtype: object
# site    media-1.meltyfashion.fr
# Name: 27301, dtype: object
# site    thumb18.shutterstock.com
# Name: 27206, dtype: object
# site    dm1files.storage.live.com
# Name: 2634, dtype: object
# site    static.cbox.ws
# Name: 27353, dtype: object
# site    user-disp.tidaltv.com
# Name: 750, dtype: object
# site    player.mediabong.net
# Name: 3651, dtype: object
# site    platform.tumblr.com
# Name: 556, dtype: object
# site    c.vindicosuite.com
# Name: 715, dtype: object
# site    serieweb.disqus.com
# Name: 27378, dtype: object
# site    www.annuaire-web-france.com
# Name: 17478, dtype: object
# site    d1447tq2m68ekg.cloudfront.net
# Name: 1643, dtype: object
# site    static.cloud-media.fr
# Name: 835, dtype: object
# site    configuration1.createmyassistant.com
# Name: 27299, dtype: object
# site    snas.nbcuni.com
# Name: 12189, dtype: object
# site    landing.r2games.com
# Name: 27310, dtype: object
# site    fs29.youwatch.org
# Name: 27267, dtype: object
# site    fr.webmaster-rank.info
# Name: 27262, dtype: object
# site    www.dessinemoiuneidee.org
# Name: 27214, dtype: object
# site    r2---sn-cg07luel.googlevideo.com
# Name: 18355, dtype: object
# site    ea.virginmobile.fr
# Name: 1979, dtype: object
# site    www22.glam.com
# Name: 9788, dtype: object
# site    dps.bing.com
# Name: 236, dtype: object
# site    s0r.c4tw.net
# Name: 316, dtype: object
# site    www.achetezfacile.com
# Name: 4965, dtype: object
# site    www.thesuburbanjungle.com
# Name: 27219, dtype: object
# site    windows.microsoft.com
# Name: 67, dtype: object
# site    bar.madmoo.com
# Name: 27318, dtype: object
# site    static1.get-the-look.fr
# Name: 2109, dtype: object
# site    divertissements.fr.msn.com
# Name: 4242, dtype: object
# site    raymichemin.canalblog.com
# Name: 27212, dtype: object
# site    dnn506yrbagrg.cloudfront.net
# Name: 513, dtype: object
# site    youtube.googleapis.com
# Name: 2329, dtype: object
# site    img.mobilenobo.net
# Name: 12615, dtype: object
# site    emea3.recruitmentplatform.com
# Name: 13688, dtype: object
# site    www.winflashplayer.com
# Name: 27360, dtype: object
# site    thumb11.shutterstock.com
# Name: 27205, dtype: object
# site    www.meltybuzz.fr
# Name: 7452, dtype: object
# site    www.kickstarter.com
# Name: 2380, dtype: object
# site    event.etam.com
# Name: 1407, dtype: object
# site    www.gralon.net
# Name: 3132, dtype: object
# site    1.drive.google.com
# Name: 776, dtype: object
# site    cdn2.freepik.com
# Name: 3537, dtype: object
# site    tags.qservz.com
# Name: 3468, dtype: object
# site    images.ted.com
# Name: 1469, dtype: object
# site    allocine-prod2.disqus.com
# Name: 7822, dtype: object
# site    assets3.lefigaro.fr
# Name: 504, dtype: object
# site    p2.storage.canalblog.com
# Name: 3282, dtype: object
# site    rbx-cdn-tpn.c4tw.net
# Name: 318, dtype: object
# site    api-leplus.nouvelobs.com
# Name: 3777, dtype: object
# site    sdc3.radio-canada.ca
# Name: 3145, dtype: object
# site    cdn4.freepik.com
# Name: 3538, dtype: object
# site    fs37.youwatch.org
# Name: 12642, dtype: object
# site    s0.karafun.com
# Name: 27244, dtype: object
# site    m3.moostik.net
# Name: 224, dtype: object
# site    ak-w3.c.ooyala.com
# Name: 9343, dtype: object
# site    cdn4711.net
# Name: 15628, dtype: object
# site    netdna.cedexis.com
# Name: 712, dtype: object
# site    us.123rf.com
# Name: 1571, dtype: object
# site    culottes-sales.fr
# Name: 27274, dtype: object
# site    www.softonic.fr
# Name: 5713, dtype: object
# site    forum.aufeminin.com
# Name: 5497, dtype: object
# site    inputtools.google.com
# Name: 1266, dtype: object
# site    fs5.youwatch.org
# Name: 27260, dtype: object
# site    p6.storage.canalblog.com
# Name: 3283, dtype: object
# site    cbks0.google.com
# Name: 668, dtype: object
# site    static1.purebreak.com
# Name: 5393, dtype: object
# site    questions.sncf.com
# Name: 16521, dtype: object
# site    payment.web-editions.fr
# Name: 27369, dtype: object
# site    www.weedoit.fr
# Name: 14258, dtype: object
# site    assets2.lefigaro.fr
# Name: 505, dtype: object
# site    fs41.youwatch.org
# Name: 27321, dtype: object
# site    a1.mzstatic.com
# Name: 27337, dtype: object
# site    settingsbucket.s3.amazonaws.com
# Name: 14242, dtype: object
# site    platform.stumbleupon.com
# Name: 555, dtype: object
# site    neto-partners.com
# Name: 27385, dtype: object
# site    log-4.previewnetworks.com
# Name: 23072, dtype: object
# site    up.adki.com
# Name: 12223, dtype: object
# site    www.maghrebdesfilms.fr
# Name: 27254, dtype: object
# site    assets6.lefigaro.fr
# Name: 507, dtype: object
# site    loadr.exelator.com
# Name: 255, dtype: object
# site    i1-js-14-3-01-10077-470179285-i.init.cedexis-r...
# Name: 27238, dtype: object
# site    piwik.framepool.com
# Name: 27225, dtype: object
# site    i1-js-14-3-01-10077-647868704-i.init.cedexis-r...
# Name: 27210, dtype: object
# site    coreg2.premiumcollect.com
# Name: 27286, dtype: object
# site    tracking.meltyfashion.fr
# Name: 27302, dtype: object
# site    cackle.ru
# Name: 27257, dtype: object
# site    ea.online.carrefour.fr
# Name: 2052, dtype: object
# site    edigitalsurvey.com
# Name: 2392, dtype: object
# site    aion.gameforge.com
# Name: 27334, dtype: object
# site    csimg.leguide.com
# Name: 2762, dtype: object
# site    www.beead.fr
# Name: 151, dtype: object
# site    commons.studyrama.com
# Name: 11363, dtype: object
# site    passets.pinterest.com
# Name: 354, dtype: object
# site    affiliation.service-voyages.com
# Name: 219, dtype: object
# site    springbreakersfullmoviestreamingfree.blogspot.com
# Name: 27329, dtype: object
# site    i11.twenga.com
# Name: 315, dtype: object
# site    image.toutlecine.com
# Name: 8619, dtype: object
# site    www.i-services.net
# Name: 14832, dtype: object
# site    api.thumbr.it
# Name: 27204, dtype: object
# site    tracker.the-other-store.net
# Name: 1047, dtype: object
# site    statics.itslearning.com
# Name: 2922, dtype: object
# site    ajax.microsoft.com
# Name: 68, dtype: object
# site    filmtimes.us
# Name: 27330, dtype: object
# site    yt4.ggpht.com
# Name: 79, dtype: object
# site    style.ad6.fr
# Name: 2954, dtype: object
# site    ssobs.nouvelobs.com
# Name: 3778, dtype: object
# site    pictures.modz.fr
# Name: 3898, dtype: object
# site    assets.vevo.com
# Name: 3370, dtype: object
# site    s374.meetrics.net
# Name: 327, dtype: object
# site    op.trpxl.com
# Name: 2388, dtype: object
# site    static.cappture.com
# Name: 13605, dtype: object
# site    pixelzirkus.gameforge.com
# Name: 15636, dtype: object
# site    farm6.static.flickr.com
# Name: 11526, dtype: object
# site    chatboxes.createmyassistant.com
# Name: 25910, dtype: object
# site    img11.hostingpics.net
# Name: 3202, dtype: object
# site    video.annuaire-web-france.com
# Name: 27170, dtype: object
# site    media.meltybuzz.fr
# Name: 2110, dtype: object
# site    rm.piximedia.fr
# Name: 1107, dtype: object
# site    imgn.dt07.net
# Name: 13125, dtype: object
# site    redir.adbutter.net
# Name: 2847, dtype: object
# site    fr.image-1.filmtrailer.com
# Name: 23071, dtype: object
# site    d2zjei5vi41j27.cloudfront.net
# Name: 27177, dtype: object
# site    fr.edeneternal.aeriagames.com
# Name: 27314, dtype: object
# site    i1-js-14-3-01-10005-16050800-i.init.cedexis-ra...
# Name: 27209, dtype: object
# site    video.ted.com
# Name: 2202, dtype: object
# site    perpetuo-onl.basilic.io
# Name: 1316, dtype: object
# site    id.impressiondesk.com
# Name: 1015, dtype: object
# site    dtm.thingsremembered.com
# Name: 970, dtype: object
# site    www.hexagonegay.com
# Name: 13345, dtype: object
# site    activistpost.net
# Name: 27186, dtype: object
# site    i1-js-14-3-01-10077-975669919-i.init.cedexis-r...
# Name: 27294, dtype: object
# site    www.forma-search.com
# Name: 21584, dtype: object
# site    dpm.zebestof.com
# Name: 8931, dtype: object
# site    www.justice.gouv.fr
# Name: 27370, dtype: object
# site    jeuxstrategie1.free.fr
# Name: 27240, dtype: object
# site    api.kickstarter.com
# Name: 27182, dtype: object
# site    banners.netopartners.com
# Name: 27386, dtype: object
# site    fstatic.iadvize.com
# Name: 292, dtype: object
# site    event-tracking.api.jobrapido.com
# Name: 13934, dtype: object
# site    i1-js-14-3-01-10165-192443829-i.init.cedexis-r...
# Name: 27272, dtype: object
# site    www.hotmail.fr
# Name: 188, dtype: object
# site    chart.googleapis.com
# Name: 3003, dtype: object
# site    main.vodonet.net
# Name: 12613, dtype: object
# site    www.20minutes.fr
# Name: 2590, dtype: object
# site    www.furplay.net
# Name: 27288, dtype: object
# site    d297h9he240fqh.cloudfront.net
# Name: 2381, dtype: object
# site    ct.buzzfeed.com
# Name: 6400, dtype: object
# site    assets1.lefigaro.fr
# Name: 508, dtype: object
# site    casale-match.dotomi.com
# Name: 540, dtype: object
# site    fs30.youwatch.org
# Name: 27169, dtype: object
# site    ptracker.be2.com
# Name: 19190, dtype: object
# site    www.gamesquat.com
# Name: 14244, dtype: object
# site    mg.dt07.net
# Name: 27185, dtype: object
# site    tracking.shopping-flux.com
# Name: 5061, dtype: object
# site    a406.idata.over-blog.com
# Name: 698, dtype: object
# site    www4.cbox.ws
# Name: 27352, dtype: object
# site    static.123rf.net
# Name: 1570, dtype: object
# site    images.hellopro.fr
# Name: 24480, dtype: object
# site    images.integral-marketing.com
# Name: 27384, dtype: object
# site    svcs.cnn.com
# Name: 3118, dtype: object
# site    i1-js-14-3-01-10077-587614011-i.init.cedexis-r...
# Name: 27303, dtype: object
# site    www.clic-diffusion.com
# Name: 6998, dtype: object
# site    eulerian.3suisses.fr
# Name: 3187, dtype: object
# site    thumb1.shutterstock.com
# Name: 9299, dtype: object
# site    www.abcompteur.com
# Name: 9270, dtype: object
# site    formation.ac-clermont.fr
# Name: 27297, dtype: object
# site    images.scribblelive.com
# Name: 23692, dtype: object
# site    a.tile.openstreetmap.org
# Name: 1207, dtype: object
# site    ultraserve.s3-website-us-east-1.amazonaws.com
# Name: 6831, dtype: object
# site    google-sync.rutarget.ru
# Name: 7364, dtype: object
# site    www.mtv.com
# Name: 27327, dtype: object
# site    fs19.youwatch.org
# Name: 27361, dtype: object
# site    freehostedscripts1.net
# Name: 27326, dtype: object
# site    i1-js-14-3-01-10077-667481799-i.init.cedexis-r...
# Name: 27295, dtype: object
# site    facebook.com
# Name: 2154, dtype: object
# site    n14.hal9000.redintelligence.net
# Name: 2813, dtype: object
# site    vindicoasset.edgesuite.net
# Name: 11033, dtype: object
# site    dtm.express.com
# Name: 2861, dtype: object
# site    static1.webedia.fr
# Name: 1157, dtype: object
# site    www.ecoleslibres.be
# Name: 27215, dtype: object
# site    feeds.bbci.co.uk
# Name: 988, dtype: object
# site    dtlilztwypawv.cloudfront.net
# Name: 27183, dtype: object
# site    www.meta-annuaire.com
# Name: 19168, dtype: object
# site    p9.storage.canalblog.com
# Name: 3284, dtype: object
# site    www.news-parfums.com
# Name: 1384, dtype: object
# site    lefigaro.fr
# Name: 514, dtype: object
# site    www.kdukvh.com
# Name: 3053, dtype: object
# site    www.programmefid.com
# Name: 14939, dtype: object
# site    use.typekit.net
# Name: 2277, dtype: object
# site    a3.mzstatic.com
# Name: 5648, dtype: object
# site    n6.hal9000.redintelligence.net
# Name: 4937, dtype: object
# site    z1.ikl.bench.cedexis.com
# Name: 8507, dtype: object
# site    static.cotecine.fr
# Name: 11338, dtype: object
# site    medias.norauto.fr
# Name: 221, dtype: object
# site    a5.mzstatic.com
# Name: 5651, dtype: object
# site    media.billetreduc.com
# Name: 27356, dtype: object
# site    img1.ndsstatic.com
# Name: 27218, dtype: object
# site    payments.spilgames.com
# Name: 14314, dtype: object
# site    asp.ergole.fr
# Name: 5909, dtype: object
# site    tag.yakarouler.com
# Name: 2153, dtype: object
# site    imvideo2.aufeminin.com
# Name: 5500, dtype: object
# site    tag.shopping-flux.com
# Name: 4045, dtype: object
# site    tracking.meltyfood.fr
# Name: 3472, dtype: object
# site    trk.adbutter.net
# Name: 2051, dtype: object
# site    medias1.tuxboard.com
# Name: 3704, dtype: object
# site    contextweb-match.dotomi.com
# Name: 1385, dtype: object
# site    nb-commons.storage.googleapis.com
# Name: 840, dtype: object
# site    5u68tkhcvx.s.ad6media.fr
# Name: 27387, dtype: object
# site    r2games.com
# Name: 27309, dtype: object
# site    partner-images.previewnetworks.com
# Name: 27293, dtype: object
# site    dtm.gap.com
# Name: 542, dtype: object
# site    measure.20mn.fr
# Name: 2591, dtype: object
# site    blogs.annuaire-web-france.com
# Name: 27171, dtype: object
# site    toolshell.org
# Name: 27213, dtype: object
# site    www.zfacts.com
# Name: 27187, dtype: object
# site    api.pinterest.com
# Name: 560, dtype: object
# site    pic.billetreduc.fr
# Name: 27355, dtype: object
# site    y.bstatic.com
# Name: 27203, dtype: object
# site    i1-js-14-3-01-10077-593659576-i.init.cedexis-r...
# Name: 27237, dtype: object
# site    fby-img.s3.amazonaws.com
# Name: 7525, dtype: object
# site    api-eu.kgoma.com
# Name: 3271, dtype: object
# site    c04a6e.r.axf8.net
# Name: 2373, dtype: object
# site    account.live.com
# Name: 5580, dtype: object
# site    beacon4.abba.accenture.com
# Name: 4272, dtype: object
# site    fr.player-feed.previewnetworks.com
# Name: 23073, dtype: object
# site    im.live-guru.com
# Name: 9761, dtype: object
# site    medext.the-oz.com
# Name: 1048, dtype: object
# site    www35f.glam.com
# Name: 9784, dtype: object
# site    a2.mzstatic.com
# Name: 5646, dtype: object
# site    dtm.potterybarnkids.com
# Name: 2423, dtype: object
# site    www.gameduell.fr
# Name: 10531, dtype: object
# site    www.homovivens.org
# Name: 1849, dtype: object
# site    n19.hal9000.redintelligence.net
# Name: 561, dtype: object
# site    images.dailyexpress.co.uk
# Name: 27175, dtype: object
# site    www.shirtinator.fr
# Name: 2824, dtype: object
# site    dtm.anthropologie.com
# Name: 2619, dtype: object
# site    dimelo-users-production.s3-eu-west-1.amazonaws...
# Name: 5380, dtype: object
# site    jslog.krxd.net
# Name: 5813, dtype: object
# site    profilepics.canalblog.com
# Name: 3277, dtype: object
# site    images.ak.instagram.com
# Name: 1397, dtype: object
# site    www.cnn.com
# Name: 3113, dtype: object
# site    dm2301files.storage.live.com
# Name: 2636, dtype: object
# site    d2j0rygefnbpzs.cloudfront.net
# Name: 3273, dtype: object
# site    assets-data.lefigaro.fr
# Name: 509, dtype: object
# site    i1-js-14-3-01-10077-975406032-i.init.cedexis-r...
# Name: 27292, dtype: object
# site    www2.gamesquat.com
# Name: 14243, dtype: object
# site    dimelo.s3.amazonaws.com
# Name: 5379, dtype: object
# site    et.eulerian.net
# Name: 5210, dtype: object
# site    n40.hal9000.redintelligence.net
# Name: 5267, dtype: object
# site    thumb7.shutterstock.com
# Name: 9301, dtype: object
# site    a.wount.com
# Name: 27283, dtype: object
# site    n34.hal9000.redintelligence.net
# Name: 8580, dtype: object
# site    www.maboutiqueregimedukan.com
# Name: 11036, dtype: object
# site    i1-js-14-3-01-10077-785351427-i.init.cedexis-r...
# Name: 27349, dtype: object
# site    static.neatorama.com
# Name: 27179, dtype: object
# site    www.i-services.com
# Name: 13563, dtype: object
# site    download.ted.com
# Name: 2398, dtype: object
# site    media-1.meltybuzz.fr
# Name: 7454, dtype: object
# site    mastertag.effiliation.com
# Name: 2457, dtype: object
# site    dtm.urbanoutfitters.com
# Name: 1421, dtype: object
# site    www.w3-directory.com
# Name: 19169, dtype: object
# site    mmotraffic.com
# Name: 15630, dtype: object
# site    fb20-auth.s3.amazonaws.com
# Name: 15566, dtype: object
# site    c.orange.fr
# Name: 3329, dtype: object
# site    www.coolflvplayer.com
# Name: 27227, dtype: object
# site    thumb9.shutterstock.com
# Name: 9300, dtype: object
# site    multimedia.fnac.com
# Name: 7453, dtype: object
# site    culottes-sales.com
# Name: 27275, dtype: object
# site    plg3.yumenetworks.com
# Name: 27291, dtype: object
# site    www.stumbleupon.com
# Name: 552, dtype: object
# site    d2aoz95szyy738.cloudfront.net
# Name: 11340, dtype: object
# site    www.gravatar.com
# Name: 568, dtype: object
# site    ressources.cash-manager.biz
# Name: 22284, dtype: object
# site    img.ohmymag.com
# Name: 3525, dtype: object
# site    www.prizee.com
# Name: 1052, dtype: object
# site    widgets.pinterest.com
# Name: 133, dtype: object
# site    cid-e729329c2e84810c.users.storage.live.com
# Name: 27350, dtype: object
# site    msfs.nspmotion.com
# Name: 1914, dtype: object
# site    res2.windows.microsoft.com
# Name: 69, dtype: object
# site    tag.wigetmedia.com
# Name: 27382, dtype: object
# site    i1-js-14-3-01-10334-827332484-i.init.cedexis-r...
# Name: 27236, dtype: object
# site    www.ticketac.com
# Name: 518, dtype: object
# site    dtm.lastcall.com
# Name: 2860, dtype: object
# site    proxy-bay-people.directory.live.com
# Name: 17, dtype: object
# site    www.lesseigneurs.fr
# Name: 27317, dtype: object
# site    dfp.oxom.com
# Name: 18728, dtype: object
# site    img.be2.com
# Name: 27315, dtype: object
# site    ww1.filmtimes.us
# Name: 27331, dtype: object
# site    promotion.shirtinator.net
# Name: 2823, dtype: object
# site    img.publicidees.com
# Name: 937, dtype: object
# site    24.media.tumblr.com
# Name: 2225, dtype: object
# site    www.blog-emploi.com
# Name: 27363, dtype: object
# site    wt-03.com
# Name: 27285, dtype: object
# site    airfrance.bannerfactory.fr
# Name: 13120, dtype: object
# site    a.intentmedia.net
# Name: 13136, dtype: object
# site    www.lafibredutri.fr
# Name: 27379, dtype: object
# site    avatars.scribblelive.com
# Name: 23693, dtype: object
# site    jeuxstrategie.free.fr
# Name: 11395, dtype: object
# site    nsa34.casimages.com
# Name: 12115, dtype: object
# site    www.be2.co.za
# Name: 19191, dtype: object
# site    2med.wat.tv
# Name: 5132, dtype: object
# site    entertaintrain.disqus.com
# Name: 27323, dtype: object
# site    d2zwke71d0db6m.cloudfront.net
# Name: 27234, dtype: object
# site    i541.photobucket.com
# Name: 27341, dtype: object
# site    springbreakersfullmoviestreamingfree.blogspot.fr
# Name: 27328, dtype: object
# site    news.google.com
# Name: 18895, dtype: object
# site    encoding.mediabong.com
# Name: 10707, dtype: object
# site    b.tile.openstreetmap.org
# Name: 1206, dtype: object
# site    cmsstatic.aionfreetoplay.com
# Name: 15640, dtype: object
# site    inspxtrc.com
# Name: 19188, dtype: object
# site    rtbp-pixel.us.metanetwork.net
# Name: 1401, dtype: object
# site    geoip.radio-canada.ca
# Name: 3159, dtype: object

# %% [markdown]
# Now let us look at the timestamps and try to characterize sessions as timeframes:

# %%
# Create a separate dataframe where we will work with timestamps
time_df = pd.DataFrame(index=train_df.index)
time_df['target'] = train_df['target']

# Find sessions' starting and ending
time_df['min'] = train_df[times].min(axis=1)
time_df['max'] = train_df[times].max(axis=1)

# Calculate sessions' duration in seconds
time_df['seconds'] = (time_df['max'] - time_df['min']) / np.timedelta64(1, 's')

time_df.head()
# Out:
#             target                 min                 max  seconds
# session_id
# 21669            0 2013-01-12 08:05:57 2013-01-12 08:05:57      0.0
# 54843            0 2013-01-12 08:37:23 2013-01-12 09:07:09   1786.0
# 77292            0 2013-01-12 08:50:13 2013-01-12 08:50:17      4.0
# 114021           0 2013-01-12 08:50:17 2013-01-12 08:50:20      3.0
# 146670           0 2013-01-12 08:50:20 2013-01-12 08:50:22      2.0

# %% [markdown]
# In order to perform the next task, generate descriptive statistics as you did in the first assignment.
#
# *In the next question, we are using the notion of "approximately the same". To be strict, let's define it: $a$ is approximately the same as $b$ ($a \approx b $) if their difference is less than or equal to 5% of the maximum between $a$ and $b$, i.e. $a \approx b \leftrightarrow \frac{|a-b|}{max(a,b)} \leq 0.05$.*
#
# ##### 2. Select all correct statements:
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread __#a3_part1_fall2019__*
#
# - on average, Alice's session is shorter than that of other users TRUE
# - more than 1% of all sessions in the dataset belong to Alice     FALSE
# - minimum and maximum durations of Alice's and other users' sessions are approximately the same TRUE
# - standard deviation of Alice's sessions duration is approximately the same as for non-Alice's sessions FALSE
# - less than a quarter of Alice's sessions are greater than or equal to 40 seconds TRUE

# %%
# You code here
#on average, Alice's session is shorter than that of other users
print(time_df[time_df['target']==0]['seconds'].mean()) #others
print(time_df[time_df['target']==1]['seconds'].mean()) #Alice
# Out:
# 139.28237232552215
# 52.29647366129734

# %%
#more than 1% of all sessions in the dataset belong to Alice
total = (time_df.shape[0])
session_qty = time_df[time_df['target']==1].describe()['target']['count']
session_qty/total*100
# Out:
# 0.905896411514389

# %%
#minimum and maximum durations of Alice's and other users' sessions are approximately the same
alice_dur_min = time_df[time_df['target']==1]['seconds'].min()
alice_dur_max = time_df[time_df['target']==1]['seconds'].max()
others_dur_min = time_df[time_df['target']==0]['seconds'].min()
others_dur_max = time_df[time_df['target']==0]['seconds'].max()
print(alice_dur_min,alice_dur_max,others_dur_min,others_dur_max)

(others_dur_max-alice_dur_max)/others_dur_max
# Out:
# 0.0 1763.0 0.0 1800.0
# 0.020555555555555556

# %%
#standard deviation of Alice's sessions duration is approximately the same as for non-Alice's sessions
alice_std = time_df[time_df['target']==1].describe()['seconds']['std']
other_std = time_df[time_df['target']==0].describe()['seconds']['std']
print(alice_std,other_std)

(other_std-alice_std)/other_std
# Out:
# 153.30901405274358 296.6535177185032
# 0.48320513698334205

# %%
#less than a quarter of Alice's sessions are greater than or equal to 40 seconds
alice_40 = time_df[(time_df['target']==1)&(time_df['seconds']>=40)].describe()['target']['count']
alice_all = time_df[(time_df['target']==1)].describe()['target']['count']
print(alice_all,alice_40)

alice_40/alice_all*100
# Out:
# 2297.0 554.0
# 24.11841532433609

# %% [markdown]
# In order to train our first model, we need to prepare the data. First of all, exclude the target variable from the training set. Now both training and test sets have the same number of columns, therefore aggregate them into one dataframe.  Thus, all transformations will be performed simultaneously on both training and test data sets.
#
# On the one hand, it leads to the fact that both data sets have one feature space (you don't have to worry that you forgot to transform a feature in some data sets). On the other hand, processing time will increase.
# For the enormously large sets it might turn out that it is impossible to transform both data sets simultaneously (and sometimes you have to split your transformations into several stages only for train/test data set).
# In our case, with this particular data set, we are going to perform all the transformations for the whole united dataframe at once, and before training the model or making predictions we will just take its appropriate part.

# %%
# Our target variable
y_train = train_df['target']

# United dataframe of the initial data 
full_df = pd.concat([train_df.drop('target', axis=1), test_df])

# Index to split the training and test data sets
idx_split = train_df.shape[0]

# %% [markdown]
# For the very basic model, we will use only the visited websites in the session (but we will not take into account timestamp features). The point behind this data selection is: *Alice has her favorite sites, and the more often you see these sites in the session, the higher probability that this is Alice's session, and vice versa.*
#
# Let us prepare the data, we will take only features `site1, site2, ... , site10` from the whole dataframe. Keep in mind that the missing values are replaced with zero. Here is how the first rows of the dataframe look like:

# %%
# Dataframe with indices of visited websites in session
full_sites = full_df[sites]
full_sites.head()
# Out:
#             site1  site2  site3  site4  site5  site6  site7  site8  site9  \
# session_id
# 21669          56     55      0      0      0      0      0      0      0
# 54843          56     55     56     55      0      0      0      0      0
# 77292         946    946    951    946    946    945    948    784    949
# 114021        945    948    949    948    945    946    947    945    946
# 146670        947    950    948    947    950    952    946    951    946
#
#             site10
# session_id
# 21669            0
# 54843            0
# 77292          946
# 114021         946
# 146670         947

# %% [markdown]
# Sessions are sequences of website indices, and data in this representation is useless for machine learning method (just think, what happens if we switched all ids of all websites).
#
# According to our hypothesis (Alice has favorite websites), we need to transform this dataframe so each website has a corresponding feature (column) and its value is equal to number of this website visits in the session. It can be done in two lines:

# %%
# sequence of indices
sites_flatten = full_sites.values.flatten()

# and the matrix we are looking for 
# (make sure you understand which of the `csr_matrix` constructors is used here)
# a further toy example will help you with it
full_sites_sparse = csr_matrix(([1] * sites_flatten.shape[0],
                                sites_flatten,
                                range(0, sites_flatten.shape[0]  + 10, 10)))[:, 1:]

# %%
full_sites_sparse.shape
# Out:
# (336358, 48371)

# %% [markdown]
# If you understand what just happened here, then you can skip the next passage (perhaps, you can handle logistic regression too?), If not, then let us figure it out.
#
# ### Important detour #1: Sparse Matrices
#
# Let us estimate how much memory it will require to store our data in the example above. Our united dataframe contains 336 thousand samples of 48 thousand integer features in each. It's easy to calculate the required amount of memory, roughly:
#
# $$336\ K * 48\ K * 8\ bytes \approx 16* 10^9 * 8\ bytes = 130\ GB,$$
#
# (that's the [exact](http://www.wolframalpha.com/input/?i=336358*48371*8+bytes) value). Obviously, ordinary mortals have no such volumes (strictly speaking, Python may allow you to create such a matrix, but it will not be easy to do anything with it). The interesting fact is that most of the elements of our matrix are zeros. If we count non-zero elements, then it will be about 1.8 million, i.е. slightly more than 10% of all matrix elements. Such a matrix, where most elements are zeros, is called sparse, and the ratio between the number of zero elements and the total number of elements is called the sparsity of the matrix.
#
# For the work with such matrices you can use `scipy.sparse` library, check [documentation](https://docs.scipy.org/doc/scipy-0.18.1/reference/sparse.html) to understand what possible types of sparse matrices are, how to work with them and in which cases their usage is most effective. You can learn how they are arranged, for example, in Wikipedia [article](https://en.wikipedia.org/wiki/Sparse_matrix).
# Note, that a sparse matrix contains only non-zero elements, and you can get the allocated memory size like this (significant memory savings are obvious):

# %%
# How much memory does a sparse matrix occupy?
print('{0} elements * {1} bytes = {2} bytes'.format(full_sites_sparse.count_nonzero(), 8, 
                                                    full_sites_sparse.count_nonzero() * 8))
# Or just like this:
print('sparse_matrix_size = {0} bytes'.format(full_sites_sparse.data.nbytes))
# Out:
# 1866898 elements * 8 bytes = 14935184 bytes
# sparse_matrix_size = 7467592 bytes

# %% [markdown]
# Let us explore how the matrix with the websites has been formed using a mini example. Suppose we have the following table with user sessions:
#
# | id | site1 | site2 | site3 |
# |---|---|---|---|
# | 1 | 1 | 0 | 0 |
# | 2 | 1 | 3 | 1 |
# | 3 | 2 | 3 | 4 |
#
# There are 3 sessions, and no more than 3 websites in each. Users visited four different sites in total (there are numbers from 1 to 4 in the table cells). And let us assume that the mapping is:
#
#  1. vk.com
#  2. habrahabr.ru
#  3. yandex.ru
#  4. ods.ai
#
# If the user has visited less than 3 websites during the session, the last few values will be zero. We want to convert the original dataframe in a way that each session has a corresponding row which shows the number of visits to each particular site. I.e. we want to transform the previous table into the following form:
#
# | id | vk.com | habrahabr.ru | yandex.ru | ods.ai |
# |---|---|---|---|---|
# | 1 | 1 | 0 | 0 | 0 |
# | 2 | 2 | 0 | 1 | 0 |
# | 3 | 0 | 1 | 1 | 1 |
#
#
# To do this, use the constructor: `csr_matrix ((data, indices, indptr))` and create a frequency table (see examples, code and comments on the links above to see how it works). Here we set all the parameters explicitly for greater clarity:

# %%
# data, create the list of ones, length of which equal to the number of elements in the initial dataframe (9)
# By summing the number of ones in the cell, we get the frequency,
# number of visits to a particular site per session
data = [1] * 9

# To do this, you need to correctly distribute the ones in cells
# Indices - website ids, i.e. columns of a new matrix. We will sum ones up grouping them by sessions (ids)
indices = [1, 0, 0, 1, 3, 1, 2, 3, 4]

# Indices for the division into rows (sessions)
# For example, line 0 is the elements between the indices [0; 3) - the rightmost value is not included
# Line 1 is the elements between the indices [3; 6)
# Line 2 is the elements between the indices [6; 9) 
indptr = [0, 3, 6, 9]

# Aggregate these three variables into a tuple and compose a matrix
# To display this matrix on the screen transform it into the usual "dense" matrix
c = csr_matrix((data, indices, indptr)).todense()

# %% [markdown]
# As you might have noticed, there are not four columns in the resulting matrix (corresponding to number of different websites) but five. A zero column has been added, which indicates if the session was shorter (in our mini example we took sessions of three). This column is excessive and should be removed from the dataframe (do that yourself).
#
# ##### 3. What is the sparsity of the matrix in our small example?
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread __#a3_part1_fall2019__*
#
# - 42%
# - 47%
# ### - 50%
# - 53%

# %%
# You code here
mtx = c[:,1:]
mtx
# Out:
# matrix([[1, 0, 0, 0],
#         [2, 0, 1, 0],
#         [0, 1, 1, 1]])

# %%
np.count_nonzero(mtx)/12
# Out:
# 0.5

# %% [markdown]
# Another benefit of using sparse matrices is that there are special implementations of both matrix operations and machine learning algorithms for them, which sometimes allows to significantly accelerate operations due to the data structure peculiarities. This applies to logistic regression as well. Now everything is ready to build our first model.
#
# ### 3. Training the first model
#
# So, we have an algorithm and data for it. Let us build our first model, using [logistic regression](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html) implementation from ` Sklearn` with default parameters. We will use the first 90% of the data for training (the training data set is sorted by time), and the remaining 10% for validation. Let's write a simple function that returns the quality of the model and then train our first classifier:

# %%
def get_auc_lr_valid(X, y, C=1.0, seed=17, ratio = 0.9):
    # Split the data into the training and validation sets
    idx = int(round(X.shape[0] * ratio))
    # Classifier training
    lr = LogisticRegression(C=C, random_state=seed, solver='liblinear').fit(X[:idx, :], y[:idx])
    # Prediction for validation set
    y_pred = lr.predict_proba(X[idx:, :])[:, 1]
    # Calculate the quality
    score = roc_auc_score(y[idx:], y_pred)
    
    return score

# %%
# %%time
# Select the training set from the united dataframe (where we have the answers)
X_train = full_sites_sparse[:idx_split, :]

# Calculate metric on the validation set
print(get_auc_lr_valid(X_train, y_train))
# Out:
# 0.9195238039167378
# Wall time: 7.23 s

# %% [markdown]
# The first model demonstrated the quality  of 0.92 on the validation set. Let's take it as the first baseline and starting point. To make a prediction on the test data set **we need to train the model again on the entire training data set** (until this moment, our model used only part of the data for training), which will increase its generalizing ability:

# %%
# Function for writing predictions to a file
def write_to_submission_file(predicted_labels, out_file,
                             target='target', index_label="session_id"):
    predicted_df = pd.DataFrame(predicted_labels,
                                index = np.arange(1, predicted_labels.shape[0] + 1),
                                columns=[target])
    predicted_df.to_csv(out_file, index_label=index_label)

# %%
# Train the model on the whole training data set
# Use random_state=17 for repeatability
# Parameter C=1 by default, but here we set it explicitly
lr = LogisticRegression(C=1.0, random_state=17, solver='liblinear').fit(X_train, y_train)

# Make a prediction for test data set
X_test = full_sites_sparse[idx_split:,:]
y_test = lr.predict_proba(X_test)[:, 1]

# Write it to the file which could be submitted
write_to_submission_file(y_test, 'baseline_1.csv')

# %% [markdown]
# If you follow these steps and upload the answer to the competition [page](https://inclass.kaggle.com/c/catch-me-if-you-can-intruder-detection-through-webpage-session-tracking2), you will get `ROC AUC = 0.90812` on the public leaderboard ("A3 baseline 1").
#
# ### 4. Model Improvement: Feature Engineering
#
# Now we are going to try to improve the quality of our model by adding new features to the data.

# %% [markdown]
# Create a feature that will be a number in YYYYMM format from the date when the session was held, for example 201407 -- year 2014 and 7th month. Thus, we will take into account the monthly [linear trend](http://people.duke.edu/~rnau/411trend.htm) for the entire period of the data provided.

# %%
# Dataframe for new features
full_new_feat = pd.DataFrame(index=full_df.index)

# Add start_month feature
full_new_feat['start_month'] = full_df['time1'].apply(lambda ts: 
                                                      100 * ts.year + ts.month).astype('float64')

# %% [markdown]
# ##### 4. Plot the graph of the number of Alice sessions versus the new feature, start_month. Choose the correct statement:
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread __#a3_part1_fall2019__*
#
# - Alice wasn't online at all for the entire period FALSE
# - From the beginning of 2013 to mid-2014, the number of Alice's sessions per month decreased FALSE
# - The number of Alice's sessions per month is generally constant for the entire period FALSE
# - From the beginning of 2013 to mid-2014, the number of Alice's sessions per month increased TRUE
#
# *Hint: the graph will be more explicit if you treat `start_month` as a categorical ordinal variable*.

# %%
c = pd.merge(train_df,full_new_feat, how='left', on='session_id')
Alice_sessions = c[c['target']==1]

# %%
x = []
y = []
for i in range(0,11):
    x.append(i)
    y.append(Alice_sessions.groupby('start_month')['start_month'].value_counts()[i])

# %%
plt.plot(x,y)

# %% [markdown]
# In this way, we have an illustration and thoughts about the usefulness of the new feature, add it to the training sample and check the quality of the new model:

# %%
# Add the new feature to the sparse matrix
tmp = full_new_feat[['start_month']].values
X_train = csr_matrix(hstack([full_sites_sparse[:idx_split,:], tmp[:idx_split,:]]))

# Compute the metric on the validation set
print(get_auc_lr_valid(X_train, y_train))
# Out:
# 0.7508354860175162

# %% [markdown]
# The quality of the model has decreased significantly. We added a feature that definitely seemed useful to us, but its usage only worsened the model. Why did it happen?
#
# ### Important detour #2: is it necessary to scale features?
#
# Here we give an intuitive reasoning (a rigorous mathematical justification for one or another aspect in linear models you can easily find on the internet). Consider the features more closely: those of them that correspond to the number of visits to a particular web-site per session vary from 0 to 10. The feature `start_month` has a completely different range: from 201301 to 201412, this means the contribution of this variable is significantly greater than the others. It would seem that problem can be avoided if we put less weight in a linear combination of attributes in this case, but in our case logistic regression with regularization is used (by default, this parameter is `C = 1`), which penalizes the model the stronger the greater its weights are. Therefore, for linear methods with regularization, it is recommended to convert features to the same scale (you can read more about the regularization, for example, [here](https://habrahabr.ru/company/ods/blog/322076/)).
#
# One way to do this is standardization: for each observation you need to subtract the average value of the feature and divide this difference by the standard deviation:
#
# $$ x^{*}_{i} = \dfrac{x_{i} - \mu_x}{\sigma_x}$$
#
# The following practical tips can be given:
# - It is recommended to scale features if they have essentially different ranges or different units of measurement (for example, the country's population is indicated in units, and the country's GNP in trillions)
# - Scale features if you do not have a reason/expert opinion to give a greater weight to any of them
# - Scaling can be excessive if the ranges of some of your features differ from each other, but they are in the same system of units (for example, the proportion of middle-aged people and people over 80 among the entire population)
# - If you want to get an interpreted model, then build a model without regularization and scaling (most likely, its quality will be worse)
# - Binary features (which take only values of 0 or 1) are usually left without conversion, (but)
# - If the quality of the model is crucial, try different options and select one where the quality is better
#
# Getting back to `start_month`, let us rescale the new feature and train the model again. This time the quality has increased:

# %%
# Add the new standardized feature to the sparse matrix
tmp = StandardScaler().fit_transform(full_new_feat[['start_month']])
X_train = csr_matrix(hstack([full_sites_sparse[:idx_split,:], tmp[:idx_split,:]]))

# Compute metric on the validation set
print(get_auc_lr_valid(X_train, y_train))
# Out:
# 0.9196986151568289

# %%
full_sites_sparse
# Out:
# <336358x48371 sparse matrix of type '<class 'numpy.int32'>'
# 	with 1866898 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ##### 5. Add to the training set a new feature "n_unique_sites" – the number of the unique web-sites in a session. Calculate how the quality on the validation set has changed
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread __#a3_part1_fall2019__*
#
# ### - It has decreased. It is better not to add a new feature.
# - It has not changed
# - It has decreased. The new feature should be scaled.
# - I am confused, and I do not know if it's necessary to scale a new feature.
#
# *Tips: use the nunique() function from `pandas`. Do not forget to include the start_month in the set. Will you scale a new feature? Why?*

# %%
# You code here
full_sites2 = full_sites.copy()
full_sites2[sites] = full_sites2[sites].replace({0:np.nan})

# %%
full_sites2.shape
# Out:
# (336358, 10)

# %%
n_unique = full_sites2.nunique(dropna='True',axis=1)

# %%
#c = pd.merge(train_df,n_unique, how='left', on='session_id')
tmp = n_unique.values.reshape(336358,1)
X_train = csr_matrix(hstack([full_sites_sparse[:idx_split,:], tmp[:idx_split,:]]))

# Compute the metric on the validation set
print(get_auc_lr_valid(X_train, y_train))
# Out:
# 0.9168283444198079

# %% [markdown]
# So, the new feature has slightly decreased the quality, so we will not use it. Nevertheless, do not rush to throw features out because they haven't performed well. They can be useful in a combination with other features (for example, when a new feature is a ratio or a product of two others).
#
# #####  6. Add two new features: start_hour and morning. Calculate the metric. Which of these features gives an improvement?
#
# The `start_hour` feature is the hour at which the session started (from 0 to 23), and the binary feature `morning` is equal to 1 if the session started in the morning and 0 if the session started later (we assume that morning means `start_hour` is equal to 11 or less).
#
# Will you scale the new features? Make your assumptions and test them in practice.
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread __#a3_part1_fall2019__*
#
# - None of the features gave an improvement :( FALSE
# - `start_hour` feature gave an improvement, and `morning` did not TRUE
# - `morning` feature gave an improvement, and `start_hour` did not TRUE
# ### - Both features gave an improvement
#
# *Tip: find suitable functions for working with time series data in [documentation](http://pandas.pydata.org/pandas-docs/stable/api.html). Do not forget to include the `start_month` feature.*

# %%
# You code here
from datetime import datetime
q6 = full_df.copy()
q6['start_hour'] = pd.to_datetime(full_df['time1'].values)#.datetime.year
q6['start_hour'] = q6['start_hour'].dt.hour
tmp = q6['start_hour'].values.reshape(336358,1)
X_train = csr_matrix(hstack([full_sites_sparse[:idx_split,:], tmp[:idx_split,:]]))
print(get_auc_lr_valid(X_train, y_train))
# Out:
# 0.9560915074948433

# %%
q6.loc[q6["start_hour"]<=11, 'morning'] = 1
q6['morning'] = q6['morning'].fillna(0)
q6['morning'] = q6['morning'].astype("int")

# %%
tmp = q6['morning'].values.reshape(336358,1)
X_train = csr_matrix(hstack([full_sites_sparse[:idx_split,:], tmp[:idx_split,:]]))
print(get_auc_lr_valid(X_train, y_train))
# Out:
# 0.9472969019462922

# %%
tmp = StandardScaler().fit_transform(full_new_feat[['start_month']])
X_train = csr_matrix(hstack([full_sites_sparse[:idx_split,:], tmp[:idx_split,:]]))

# Compute metric on the validation set
print(get_auc_lr_valid(X_train, y_train))
# Out:
# 0.9196986151568289

# %%
q6.head()
# Out:
#             site1               time1  site2               time2  site3  \
# session_id
# 21669          56 2013-01-12 08:05:57     55 2013-01-12 08:05:57      0
# 54843          56 2013-01-12 08:37:23     55 2013-01-12 08:37:23     56
# 77292         946 2013-01-12 08:50:13    946 2013-01-12 08:50:14    951
# 114021        945 2013-01-12 08:50:17    948 2013-01-12 08:50:17    949
# 146670        947 2013-01-12 08:50:20    950 2013-01-12 08:50:20    948
#
#                          time3  site4               time4  site5  \
# session_id
# 21669                      NaT      0                 NaT      0
# 54843      2013-01-12 09:07:07     55 2013-01-12 09:07:09      0
# 77292      2013-01-12 08:50:15    946 2013-01-12 08:50:15    946
# 114021     2013-01-12 08:50:18    948 2013-01-12 08:50:18    945
# 146670     2013-01-12 08:50:20    947 2013-01-12 08:50:21    950
#
#                          time5  ...               time7 site8  \
# session_id                      ...
# 21669                      NaT  ...                 NaT     0
# 54843                      NaT  ...                 NaT     0
# 77292      2013-01-12 08:50:16  ... 2013-01-12 08:50:16   784
# 114021     2013-01-12 08:50:18  ... 2013-01-12 08:50:19   945
# 146670     2013-01-12 08:50:21  ... 2013-01-12 08:50:21   951
#
#                          time8 site9               time9 site10  \
# session_id
# 21669                      NaT     0                 NaT      0
# 54843                      NaT     0                 NaT      0
# 77292      2013-01-12 08:50:16   949 2013-01-12 08:50:17    946
# 114021     2013-01-12 08:50:19   946 2013-01-12 08:50:19    946
# 146670     2013-01-12 08:50:22   946 2013-01-12 08:50:22    947
#
#                         time10 start_hour  morning start_month
# session_id
# 21669                      NaT          8        1    201301.0
# 54843                      NaT          8        1    201301.0
# 77292      2013-01-12 08:50:17          8        1    201301.0
# 114021     2013-01-12 08:50:20          8        1    201301.0
# 146670     2013-01-12 08:50:22          8        1    201301.0
#
# [5 rows x 23 columns]

# %%
q6['start_month'] = full_df['time1'].apply(lambda ts: 
                                                      100 * ts.year + ts.month).astype('float64')

# %% [markdown]
# ### 5. Regularization and Parameter Tuning
#
# We have introduced features that improve the quality of our model in comparison with the first baseline. Can we do even better? After we have changed the training and test sets, it almost always makes sense to search for the optimal hyperparameters - the parameters of the model that do not change during training.
#
# For example, in week 3, you learned that, in decision trees, the depth of the tree is a hyperparameter, but the feature by which splitting occurs and its threshold is not.
#
# In the logistic regression that we use, the weights of each feature are changing, and we find their optimal values during training; meanwhile, the regularization parameter remains constant. This is the hyperparameter that we are going to optimize now.
#
# Calculate the quality on a validation set with a regularization parameter, which is equal to 1 by default:

# %%
# Dataframe for new features
full_new_feat = pd.DataFrame(index=full_df.index)

# Add start_month feature
full_new_feat['start_month'] = full_df['time1'].apply(lambda ts: 
                                                      100 * ts.year + ts.month).astype('float64')

# %%
full_new_feat = pd.merge(full_new_feat, q6['start_hour'], on="session_id", how='left')

# %%
full_new_feat = pd.merge(full_new_feat, q6['morning'], on="session_id", how='left')

# %%
# Compose the training set
tmp_scaled = StandardScaler().fit_transform(q6[['start_month', 
                                                           'start_hour', 
                                                           'morning']])
X_train = csr_matrix(hstack([full_sites_sparse[:idx_split,:], 
                             tmp_scaled[:idx_split,:]]))

# Capture the quality with default parameters
score_C_1 = get_auc_lr_valid(X_train, y_train)
print(score_C_1)
# Out:
# 0.9591528176311175

# %% [markdown]
# We will try to beat this result by optimizing the regularization parameter. We will take a list of possible values of C and calculate the quality metric on the validation set for each of C-values:

# %%
# List of possible C-values
Cs = np.logspace(-3, 1, 10)

# You code here
lr2 = LogisticRegression(C=1, random_state=17, solver='liblinear')

# %% [markdown]
# Plot the graph of the quality metric (AUC-ROC) versus the value of the regularization parameter. The value of quality metric corresponding to the default value of C=1 is represented by a horizontal dotted line:

# %%
graph_y = []
for i in Cs:
    lr2 = LogisticRegression(C=i, random_state=17, solver='liblinear')
    lr2.fit(X_train[:idx, :], y_train[:idx])
    y_pred = lr2.predict_proba(X_train[idx:, :])[:, 1]
    score = roc_auc_score(y_train[idx:], y_pred)
    graph_y.append(score)
    print("C: " + str(i) +"   Score: " + str(score))
# Out:
# C: 0.001   Score: 0.7366201469501326
# C: 0.0027825594022071257   Score: 0.8036353491877165
# C: 0.007742636826811269   Score: 0.8717010794216676
# C: 0.021544346900318832   Score: 0.9095437879512485
# C: 0.05994842503189409   Score: 0.9183501683501684
# C: 0.1668100537200059   Score: 0.9192129025791149
# C: 0.46415888336127775   Score: 0.9186320099609195
# C: 1.2915496650148828   Score: 0.9175902376225189
# C: 3.593813663804626   Score: 0.9154118903042863
# C: 10.0   Score: 0.9129323785439281

# %%
plt.plot(Cs, graph_y)

# %%
Cs[5]
# Out:
# 0.1668100537200059

# %% [markdown]
# ##### 7. What is the value of parameter C (if rounded to 2 decimals) that corresponds to the highest model quality?
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread __#a3_part1_fall2019__*
#
# ### - 0.17
# - 0.46
# - 1.29
# - 3.14

# %%
# You code here

# %% [markdown]
# For the last task in this assignment: train the model using the optimal regularization parameter you found (do not round up to two digits like in the last question). If you do everything correctly and submit your solution, you should see `ROC AUC = 0.92784` on the public leaderboard ("A3 baseline 2"):

# %%
# Prepare the training and test data
tmp_scaled = StandardScaler().fit_transform(q6[['start_month', 'start_hour', 
                                                           'morning']])
X_train = csr_matrix(hstack([full_sites_sparse[:idx_split,:], 
                             tmp_scaled[:idx_split,:]]))
X_test = csr_matrix(hstack([full_sites_sparse[idx_split:,:], 
                            tmp_scaled[idx_split:,:]]))

# Train the model on the whole training data set using optimal regularization parameter
lr = LogisticRegression(C=Cs[5], random_state=17, solver='liblinear').fit(X_train, y_train)

# Make a prediction for the test set
y_test = lr.predict_proba(X_test)[:, 1]

# Write it to the submission file
write_to_submission_file(y_test, 'baseline_2.csv')

# %% [markdown]
# In this part of the assignment, you have learned how to use sparse matrices, train logistic regression models, create new features and selected the best ones, learned why you need to scale features, and how to select hyperparameters. That's a lot!

# %% [markdown]
# # Subpart 2. Freeride

# %% [markdown]
# <img src='../../img/snowboard.jpg' width=70%>
#
# *Yorko in Sheregesh, the best place in Russia for snowboarding and skiing.*

# %% [markdown]
# In this part, you'll need to beat the 2 more baselines mentioned in the beginning of this assignment. No more step-by-step instructions. But it'll be very helpful for you to study the Kernel "[Model validation in a competition](https://www.kaggle.com/kashnitsky/model-validation-in-a-competition)".
#
# Here are a few tips for finding new features: think about what you can come up with using existing features, try multiplying or dividing two of them, justify or decline your hypotheses with plots, extract useful information from time series data (time1 ... time10), do not hesitate to convert an existing feature (for example, take a logarithm), etc. Checkout other [Kernels](https://www.kaggle.com/c/catch-me-if-you-can-intruder-detection-through-webpage-session-tracking2/kernels). We encourage you to try new ideas and models - it's fun!

# %% [markdown]
# Заметка:
# Попробовать фичи
# 0 или 1 в те периоды, когда Алиса не была онлайн
# Среднее время между открытиями новых страниц
