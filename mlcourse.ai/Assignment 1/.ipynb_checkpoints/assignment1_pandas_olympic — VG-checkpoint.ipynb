# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg" />
#
# ## [mlcourse.ai](https://mlcourse.ai) – Open Machine Learning Course
# Author: Arina Lopukhova (@erynn). Edited by [Yury Kashnitskiy](https://yorko.github.io) (@yorko) and Vadim Shestopalov (@vchulski). This material is subject to the terms and conditions of the [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/) license. Free use is permitted for any non-commercial purpose.

# %% [markdown]
# # <center>Assignment #1. Fall 2019
# ## <center>Exploratory data analysis of Olympic games with Pandas
#
# <img src='../../img/olympic_logo.png' width=50%>

# %% [markdown]
# Prior to working on the assignment, you'd better check out the corresponding course material:
#  - [Exploratory data analysis with Pandas](https://nbviewer.jupyter.org/github/Yorko/mlcourse_open/blob/master/jupyter_english/topic01_pandas_data_analysis/topic1_pandas_data_analysis.ipynb?flush_cache=true), the same as an interactive web-based [Kaggle Kernel](https://www.kaggle.com/kashnitsky/topic-1-exploratory-data-analysis-with-pandas)
#  - first lectures in mlcourse.ai [YouTube playlist ](https://www.youtube.com/watch?v=QKTuw4PNOsU&list=PLVlY_7IJCMJeRfZ68eVfEcu-UcN9BbwiX)
#  - you can also practice with demo assignments, which are simpler and already shared with solutions: [A1 demo](https://www.kaggle.com/kashnitsky/a1-demo-pandas-and-uci-adult-dataset), [solution](https://www.kaggle.com/kashnitsky/a1-demo-pandas-and-uci-adult-dataset-solution)
#
# ### Your task is to:
#  1. write code and perform computations in the cells below
#  2. choose answers in the [webform](https://docs.google.com/forms/d/1JxhQ9Bg4OpM3E5N47ZuRbILgDuMRbvEnUbDMZK8L-NU). Solutions will be shared only with those who've filled in this form
#  3. submit answers with some email and **remember it**! This will be your ID during the course. Specify your real full name in the form as well (no nicks allowed in the final top-100 [rating](https://mlcourse.ai/rating)). If in doubt, you can re-submit the form till the deadline for A1, no problem, but stick to only one email.
#
# ### <center> Deadline for A1: 2019 September 15, 20:59 GMT (London time)
#
# You'll get up to 10 credits for this assignment.
#
# ### How to get help
# In [ODS Slack](https://opendatascience.slack.com) (if you still don't have access, fill in the [form](https://docs.google.com/forms/d/10HAN5huM996snUKjsNYyT_oOlm2uOsTKulKurb3oiNM/) mentioned on the mlcourse.ai main page), we have a channel **#mlcourse_ai_news** with announcements from the course team.
# You can discuss the course content freely in the **#mlcourse_ai** channel (we still have a huge Russian-speaking group, they have a separate channel **#mlcourse_ai_rus**).
#
# Here's how you reply in a thread (press this dialog icon to drill down into a thread):
#
# <img src="../../img/start_a_thread.png" />
#
# Please stick to special threads *a1_q1-5_fall2019* and *a1_q6-10_fall2019* in **#mlcourse_ai_news** for your questions on A1. Help each other without sharing correct code and answers. Our TA **Vadim @vchulski** is there to help (only in the mentioned thread, do not write to him directly).
#
# Lastly, you can save useful messages by pinning them, further you can find pinned items on the top, just below the channel name:
#
# <img src="../../img/pinned_item.png" />
#
# ### Assignment
# __There are ten questions about 120 years of Olympic history in this task. Your task is to fill in the missing Python code and choose answers in [this web-form](https://docs.google.com/forms/d/1JxhQ9Bg4OpM3E5N47ZuRbILgDuMRbvEnUbDMZK8L-NU).__

# %% [markdown]
# Download the file `athlete_events.csv` from [here](https://drive.google.com/file/d/1f5v6Z2ayc7h698FG_98wP5x1Y2zZQeox/view?usp=sharing) (scraped by [rgriffin](https://www.randigriffin.com/) from www.sports-reference.com). The dataset has the following features:
#
# - __ID__ - Unique number for each athlete
# - __Name__ - Athlete's name
# - __Sex__ - M or F
# - __Age__ - Integer
# - __Height__ - In centimeters
# - __Weight__ - In kilograms
# - __Team__ - Team name
# - __NOC__ - National Olympic Committee 3-letter code
# - __Games__ - Year and season
# - __Year__ - Integer
# - __Season__ - Summer or Winter
# - __City__ - Host city
# - __Sport__ - Sport
# - __Event__ - Event
# - __Medal__ - Gold, Silver, Bronze, or NA

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
# Change the path to the dataset file if needed. 
PATH = '../../data/athlete_events.csv'

# %%
data = pd.read_csv(PATH)
data.head()
#data[data["Team"]=="Switzerland"]
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# __1. How old were the youngest male and female participants of the 1992 Olympics?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 16 and 15
# - 14 and 13
# - 13 and 11
# - 11 and 12

# %%
print(data[(data["Year"]==1992)&(data["Sex"]=="M")].min()["Age"])
print(data[(data["Year"]==1992)&(data["Sex"]=="F")].min()["Age"])
# Out:
# 11.0
# 12.0

# %% [markdown]
# __2. What was the percentage of male basketball players among all the male participants of the 2012 Olympics? Round the answer to the first decimal.__
#
# *Hint:* here and further if needed drop duplicated sportsmen to count only unique ones.
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 0.2
# - 1.5
# - 2.5
# - 7.7

# %%
total_M = data[(data["Year"]==2012)&(data["Sex"]=="M")]
total_M = total_M.drop_duplicates("ID")

basket_M = total_M[total_M["Sport"]=="Basketball"]

basket_M.shape[0]/total_M.shape[0]*100
# Out:
# 2.4560805048609926

# %% [markdown]
# __3. What are the mean and standard deviation of height for female tennis players who participated in the 2000 Olympics? Round the answer to the first decimal.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 171.8 and 6.5
# - 179.4 and 10
# - 180.7 and 6.7
# - 182.4 and 9.1

# %%
(data[(data["Year"]==2000)&(data["Sex"]=="F")&(data["Sport"]=="Tennis")].drop_duplicates("ID").mean()["Height"])
# Out:
# 171.8068181818182

# %%
(data[(data["Year"]==2000)&(data["Sex"]=="F")&(data["Sport"]=="Tennis")].drop_duplicates("ID").describe())
# Out:
#                   ID        Age      Height     Weight    Year
# count      89.000000  89.000000   88.000000  88.000000    89.0
# mean    75532.955056  23.280899  171.806818  61.693182  2000.0
# std     39460.688296   3.447624    6.563322   6.250256     0.0
# min      4723.000000  17.000000  150.000000  52.000000  2000.0
# 25%     42361.000000  21.000000  168.000000  57.000000  2000.0
# 50%     75706.000000  24.000000  172.000000  60.000000  2000.0
# 75%    108845.000000  26.000000  176.000000  65.000000  2000.0
# max    135502.000000  30.000000  191.000000  79.000000  2000.0

# %% [markdown]
# __4. Find a sportsman who participated in the 2006 Olympics, with the highest weight among other participants of the same Olympics. What sport did he or she do?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - Judo
# - Bobsleigh
# - Skeleton
# - Boxing

# %%
data[(data["Year"]==2006)].sort_values("Weight", ascending=False)
# Out:
#             ID                                   Name Sex   Age  Height  \
# 8102      4476                      Patrick R. Antaki   M  41.0   185.0
# 38615    19867                             Zdeno Chra   M  28.0   206.0
# 129597   65246                            Kevin Kuske   M  27.0   196.0
# 129596   65246                            Kevin Kuske   M  27.0   196.0
# 48536    25017             Matthew John "Matt" Dallow   M  34.0   190.0
# 128126   64528                           Pavel Kubina   M  28.0   196.0
# 188177    38.0       North Korea  PRK  2006 Winter  2006  Winter  Torino
# 32001      NaN          Canada-1  CAN  2006 Winter  2006  Winter  Torino
# 70864      NaN           Ireland  IRL  2006 Winter  2006  Winter  Torino
# 100598     NaN     United States  USA  2006 Winter  2006  Winter  Torino
# 109183     NaN            Sweden  SWE  2006 Winter  2006  Winter  Torino
# 119378     NaN        Costa Rica  CRC  2006 Winter  2006  Winter  Torino
# 137410     NaN            Canada  CAN  2006 Winter  2006  Winter  Torino
# 143044     NaN          Canada-2  CAN  2006 Winter  2006  Winter  Torino
# 149265     NaN          Canada-1  CAN  2006 Winter  2006  Winter  Torino
# 209800     NaN            Canada  CAN  2006 Winter  2006  Winter  Torino
# 211494     NaN              Iran  IRI  2006 Winter  2006  Winter  Torino
# 211495     NaN              Iran  IRI  2006 Winter  2006  Winter  Torino
# 211812     NaN            Canada  CAN  2006 Winter  2006  Winter  Torino
# 215400     NaN           Senegal  SEN  2006 Winter  2006  Winter  Torino
# 215401     NaN           Senegal  SEN  2006 Winter  2006  Winter  Torino
# 215402     NaN           Senegal  SEN  2006 Winter  2006  Winter  Torino
# 261779     NaN          Canada-2  CAN  2006 Winter  2006  Winter  Torino
#
#                             Sport  \
# 8102                     Skeleton
# 38615                  Ice Hockey
# 129597                  Bobsleigh
# 129596                  Bobsleigh
# 48536                   Bobsleigh
# 128126                 Ice Hockey
# 20721                  Ice Hockey
# 111387                 Ice Hockey
# 93071                   Bobsleigh
# 93070                   Bobsleigh
# 100887                  Bobsleigh
# 100886                  Bobsleigh
# 58578                   Bobsleigh
# 58577                   Bobsleigh
# 91881                  Ice Hockey
# 92541                   Bobsleigh
# 92542                   Bobsleigh
# 48998                   Bobsleigh
# 95518                   Bobsleigh
# 48997                   Bobsleigh
# 77507                   Bobsleigh
# 72546                     Curling
# 254849                  Bobsleigh
# 254850                  Bobsleigh
# 128539                  Bobsleigh
# 125792                 Ice Hockey
# 194142                 Ice Hockey
# 203631                  Bobsleigh
# 203630                  Bobsleigh
# 125741                 Ice Hockey
# 121828                 Ice Hockey
# 97412                   Bobsleigh
# 8353                   Ice Hockey
# 146970                 Ice Hockey
# 97411                   Bobsleigh
# 80602                  Ice Hockey
# 214280                 Ice Hockey
# 20509                   Bobsleigh
# 125213                 Ice Hockey
# 126105                 Ice Hockey
# 147613                 Ice Hockey
# 20508                   Bobsleigh
# 123302                 Ice Hockey
# 22432                   Bobsleigh
# 80185                   Bobsleigh
# 22431                   Bobsleigh
# 270605                  Bobsleigh
# 270606                  Bobsleigh
# 122049                  Bobsleigh
# 253915                 Ice Hockey
# ...                           ...
# 264292  Short Track Speed Skating
# 4045                     Biathlon
# 74282                Snowboarding
# 4046                     Biathlon
# 4044                     Biathlon
# 51105                  Ice Hockey
# 235968  Short Track Speed Skating
# 75538   Short Track Speed Skating
# 75537   Short Track Speed Skating
# 189769             Figure Skating
# 220119             Figure Skating
# 126105                        Ice Hockey Men's Ice Hockey     NaN
# 147613                        Ice Hockey Men's Ice Hockey  Bronze
# 20508                                 Bobsleigh Men's Two     NaN
# 123302                        Ice Hockey Men's Ice Hockey     NaN
# 22432                                Bobsleigh Men's Four     NaN
# 80185                                 Bobsleigh Men's Two     NaN
# 22431                                 Bobsleigh Men's Two     NaN
# 270605                                Bobsleigh Men's Two     NaN
# 270606                               Bobsleigh Men's Four  Silver
# 122049                               Bobsleigh Men's Four     NaN
# 253915                        Ice Hockey Men's Ice Hockey     NaN
# ...                                                   ...     ...
# 264292  Short Track Speed Skating Women's 3,000 metres...     NaN
# 4045                       Biathlon Women's 15 kilometres     NaN
# 74282                       Snowboarding Women's Halfpipe     NaN
# 4046              Biathlon Women's 4 x 6 kilometres Relay     NaN
# 4044               Biathlon Women's 7.5 kilometres Sprint     NaN
# 51105                       Ice Hockey Women's Ice Hockey     NaN
# 235968       Short Track Speed Skating Women's 500 metres     NaN
# 75538   Short Track Speed Skating Women's 3,000 metres...    Gold
# 75537        Short Track Speed Skating Women's 500 metres     NaN
# 189769                         Figure Skating Mixed Pairs     NaN
# 220119                   Figure Skating Mixed Ice Dancing     NaN
# 235969  Short Track Speed Skating Women's 3,000 metres...     NaN
# 226207                         Figure Skating Mixed Pairs     NaN
# 59194                    Figure Skating Mixed Ice Dancing     NaN
# 181140                         Figure Skating Mixed Pairs     NaN
# 231569                    Freestyle Skiing Women's Moguls     NaN
# 231728                     Figure Skating Women's Singles     NaN
# 187284                         Figure Skating Mixed Pairs     NaN
# 155949                     Figure Skating Women's Singles     NaN
# 92433                             Curling Women's Curling     NaN
# 38092                    Figure Skating Mixed Ice Dancing     NaN
# 218110                         Figure Skating Mixed Pairs  Bronze
# 267192                         Figure Skating Mixed Pairs     NaN
# 242442                         Figure Skating Mixed Pairs    Gold
# 167920                      Snowboarding Women's Halfpipe     NaN
# 254115                         Figure Skating Mixed Pairs     NaN
# 30125                       Snowboarding Women's Halfpipe     NaN
# 43199                      Figure Skating Women's Singles  Silver
# 60666                     Freestyle Skiing Women's Moguls     NaN
# 103190                         Figure Skating Mixed Pairs     NaN
# 174721                         Figure Skating Mixed Pairs     NaN
# 117208                   Figure Skating Mixed Ice Dancing     NaN
# 77462                      Figure Skating Women's Singles     NaN
# 188177                         Figure Skating Mixed Pairs     NaN
# 32001                          Figure Skating Mixed Pairs     NaN
# 70864                    Alpine Skiing Men's Giant Slalom     NaN
# 100598                     Figure Skating Women's Singles     NaN
# 109183                    Snowboarding Men's Boardercross     NaN
# 119378           Cross Country Skiing Men's 15 kilometres     NaN
# 137410                     Figure Skating Women's Singles     NaN
# 143044                   Figure Skating Mixed Ice Dancing     NaN
# 149265                         Figure Skating Mixed Pairs     NaN
# 209800                       Figure Skating Men's Singles     NaN
# 211494                   Alpine Skiing Men's Giant Slalom     NaN
# 211495                         Alpine Skiing Men's Slalom     NaN
# 211812                       Figure Skating Men's Singles     NaN
# 215400                        Alpine Skiing Men's Super G     NaN
# 215401                   Alpine Skiing Men's Giant Slalom     NaN
# 215402                         Alpine Skiing Men's Slalom     NaN
# 261779                   Figure Skating Mixed Ice Dancing     NaN
#
# [4382 rows x 15 columns]

# %% [markdown]
# __5. How many times did John Aalberg participate in the Olympics held in different years?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 0
# - 1
# - 2
# - 3

# %%
data[(data["Name"]=="John Aalberg")].drop_duplicates("Year") #.shape[0]
# Out:
#     ID          Name Sex   Age  Height  Weight           Team  NOC  \
# 18   7  John Aalberg   M  31.0   183.0    72.0  United States  USA
# 22   7  John Aalberg   M  33.0   183.0    72.0  United States  USA
#
#           Games  Year  Season         City                 Sport  \
# 18  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 22  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
#
#                                        Event Medal
# 18  Cross Country Skiing Men's 10 kilometres   NaN
# 22  Cross Country Skiing Men's 10 kilometres   NaN

# %% [markdown]
# __6. How many gold medals in tennis did sportspeople from the Switzerland team win at the 2008 Olympics? Count every medal from every sportsperson.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - 0
# - 1
# - 2
# - 3

# %%
data[(data["Year"]==2008)&(data["NOC"]=="SUI")&(data["Sport"]=="Tennis")&(data["Medal"]=="Gold")] #.shape[0]
# Out:
#             ID                Name Sex   Age  Height  Weight         Team  \
# 67290    34396       Roger Federer   M  26.0   185.0    80.0  Switzerland
# 257672  129042  Stanislas Wawrinka   M  23.0   183.0    79.0  Switzerland
#
#         NOC        Games  Year  Season     City   Sport                 Event  \
# 67290   SUI  2008 Summer  2008  Summer  Beijing  Tennis  Tennis Men's Doubles
# 257672  SUI  2008 Summer  2008  Summer  Beijing  Tennis  Tennis Men's Doubles
#
#        Medal
# 67290   Gold
# 257672  Gold

# %% [markdown]
# __7. Is it true that Spain won fewer medals than Italy at the 2016 Olympics? Do not consider NaN values in _Medal_ column.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - Yes
# - No

# %%
Spain = data[(data["Year"]==2016)&(data["NOC"]=="ESP")].dropna(subset=["Medal"]).shape[0]
Italy = data[(data["Year"]==2016)&(data["NOC"]=="ITA")].dropna(subset=["Medal"]).shape[0]

print(Spain, " ", Italy)
# Out:
# 45   72

# %% [markdown]
# __8. What age category did the fewest and the most participants of the 2008 Olympics belong to?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - [45-55] and [25-35) correspondingly
# - [45-55] and [15-25) correspondingly
# - [35-45) and [25-35) correspondingly
# - [45-55] and [35-45) correspondingly

# %%
columns_to_show = ['Year']
a = data[data["Year"]==2008]
a.drop_duplicates("ID")
ranges = [14,24,34,44,55,65]
a.groupby(pd.cut(a["Age"],ranges)).describe()
# Out:
#               ID                                                          \
#            count          mean           std      min       25%      50%
# Age
# (14, 24]  6294.0  68861.187321  39819.427105     67.0  34001.00  68621.0
# (24, 34]  6367.0  69372.535888  39191.006035     21.0  35894.00  69526.0
# (34, 44]   790.0  66322.392405  39166.799891     93.0  30964.25  67547.5
# (44, 55]   119.0  71052.899160  38045.348944   1848.0  33398.50  71236.0
# (55, 65]    11.0  74595.636364  35664.601535  17461.0  65469.50  69132.0
#
#                                   Age                                         \
#                 75%       max   count       mean       std   min   25%   50%
# Age
# (14, 24]  104203.75  135530.0  6294.0  21.218939  2.267657  15.0  20.0  22.0
# (24, 34]  102818.00  135557.0  6367.0  28.263232  2.614059  25.0  26.0  28.0
# (34, 44]   99974.75  135292.0   790.0  37.697468  2.569366  35.0  36.0  37.0
# (44, 55]  104874.00  135501.0   119.0  47.773109  2.624645  45.0  46.0  47.0
# (55, 65]   82280.00  132159.0    11.0  58.727273  1.954017  56.0  57.5  58.0
#
#                       Height                                              \
#            75%   max   count        mean        std    min    25%    50%
# Age
# (14, 24]  23.0  24.0  6202.0  174.834086  11.872653  137.0  167.0  175.0
# (24, 34]  30.0  34.0  6320.0  177.589082  11.122958  140.0  169.0  178.0
# (34, 44]  39.0  44.0   780.0  176.279487   9.842474  152.0  169.0  175.0
# (44, 55]  49.0  55.0   119.0  175.974790   8.776376  152.0  170.0  175.0
# (55, 65]  60.5  61.0    11.0  172.090909  11.674370  157.0  162.5  171.0
#
#                         Weight                                                \
#             75%    max   count       mean        std   min   25%   50%   75%
# Age
# (14, 24]  183.0  218.0  6194.0  68.808767  15.303429  28.0  58.0  67.0  78.0
# (24, 34]  185.0  226.0  6324.0  73.592505  16.191315  39.0  62.0  71.0  83.0
# (34, 44]  183.0  208.0   778.0  73.782134  15.316915  44.0  63.0  72.0  84.0
# (44, 55]  182.0  193.0   117.0  75.675214  15.840710  48.0  66.0  73.0  84.0
# (55, 65]  181.5  191.0    11.0  72.454545  13.559968  53.0  67.0  72.0  76.0
#
#                    Year
#             max   count    mean  std     min     25%     50%     75%     max
# Age
# (14, 24]  214.0  6294.0  2008.0  0.0  2008.0  2008.0  2008.0  2008.0  2008.0
# (24, 34]  170.0  6367.0  2008.0  0.0  2008.0  2008.0  2008.0  2008.0  2008.0
# (34, 44]  140.0   790.0  2008.0  0.0  2008.0  2008.0  2008.0  2008.0  2008.0
# (44, 55]  125.0   119.0  2008.0  0.0  2008.0  2008.0  2008.0  2008.0  2008.0
# (55, 65]   99.0    11.0  2008.0  0.0  2008.0  2008.0  2008.0  2008.0  2008.0

# %% [markdown]
# __9. Is it true that there were Summer Olympics held in Atlanta? Is it true that there were Winter Olympics held in Squaw Valley?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - Yes, Yes
# - Yes, No
# - No, Yes
# - No, No

# %%
Atl = data[(data["City"]=="Atlanta")]["Season"].drop_duplicates()
SqV = data[(data["City"]=="Squaw Valley")]["Season"].drop_duplicates()
print(Atl, "\n", SqV)
# Out:
# 32    Summer
# Name: Season, dtype: object
#  83    Winter
# Name: Season, dtype: object

# %% [markdown]
# __10. What is the absolute difference between the number of unique sports at the 1986 Olympics and 2002 Olympics?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - 3
# - 10
# - 15
# - 27

# %%
a = data[(data["Year"]==1986)]["Sport"].drop_duplicates().shape[0]
b = data[(data["Year"]==2002)]["Sport"].drop_duplicates().shape[0]
print(a, " ", b)
# Out:
# 0   15

# %% [markdown]
# That's it! Now go and do 30 push-ups! :)
